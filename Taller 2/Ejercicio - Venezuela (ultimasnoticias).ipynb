# %%
import json
import w3lib.html
import random
import os
import datetime
import requests
import string
import calendar
import html
import locale 
import validators
from requests_html import HTML
from requests_html import HTMLSession

# %% [markdown]
# ## Parte 1: Crawling
#
#
# ### 1. URL _seed_
#
# El sitio web esta basado en wordpress por lo que consulte la documentación para obtener los datos a partir de la api

# %%
SEED_CRAWL = 'https://www.ultimasnoticias.com.ve/wp-json/wp/v2/posts'

# %% [markdown]
# * Si se desea obtener otras paginas se añade a la url ?page=NUMERO_DE_PAGINA
# * El numero de paginas esta en los headers del request, variable x-wp-totalpages

# %% [markdown]
# ### 2. Class _Crawler_

# %%
import random
import requests
from requests_html import HTMLSession
from requests_html import HTML
import os
import json
import validators

# %%
class Crawler:
    
    USER_AGENT_LIST = [
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1",
        "Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24"
]

    #query_extract_all_href=QUERY_URL

    all_json_to_send = []
    
    def _init_(self):
        pass
    
    def parse(self, response):
        ''' do something with this parser '''
        self.all_extracted_href = []
        json_data = json.loads(response.html.html)
        for url_data in json_data:
           
            json_to_send = {}
            json_to_send["url"] = url_data["guid"]["rendered"]
            json_to_send["title"] = url_data["title"]["rendered"]
            json_to_send["date"] = url_data["date_gmt"]
            self.all_json_to_send.append(json_to_send)      
         
            

    def start_request(self,url,header=dict()):
        session = HTMLSession()
        header['user-agent'] = random.choice(self.USER_AGENT_LIST)
        response = session.get(url)        
        return response

# %%
crawler = Crawler()
response = crawler.start_request(SEED_CRAWL)

# %%
response.html.html
# Out:
# '[{"id":2156682,"date":"2020-10-12T14:49:55","date_gmt":"2020-10-12T18:49:55","guid":{"rendered":"http:\\/\\/ultimasnoticias.com.ve\\/?p=2156682"},"modified":"2020-10-12T14:49:57","modified_gmt":"2020-10-12T18:49:57","slug":"conceden-premio-a-la-trayectoria-del-maestro-jose-antonio-abreu","status":"publish","type":"post","link":"https:\\/\\/ultimasnoticias.com.ve\\/noticias\\/chevere\\/conceden-premio-a-la-trayectoria-del-maestro-jose-antonio-abreu\\/","title":{"rendered":"Conceden premio a la trayectoria del maestro Jos\\u00e9 Antonio Abreu","gt_translate_keys":[{"key":"rendered","format":"text"}]},"content":{"rendered":"\\n<p>Este domingo la prestigiosa organizaci\\u00f3n surcoreana, Isang Yun, anunci\\u00f3 el veredicto que este a\\u00f1o 2020 concede el reconocimiento especial a la figura del fundador de El Sistema, el maestro venezolano, Jos\\u00e9 A Abreu, destacando su vida y su legado educativo, el cual \\u00abvive en los ni\\u00f1os alrededor del mundo\\u00bb.<\\/p>\\n\\n\\n\\n<p>La fundaci\\u00f3n que desde el a\\u00f1o 2003 organiza una importante competencia musical, destac\\u00f3 la labor realizada por el maestro Abreu, tras su paso como director, pianista, economista y educador venezolano, creador de El Sistema, est\\u00e1 destinado a apoyar los proyectos de nuestra instituci\\u00f3n a trav\\u00e9s de la Unesco en Nueva York, rese\\u00f1a nota de prensa.<\\/p>\\n\\n\\n\\n<p>Dicha postulaci\\u00f3n se present\\u00f3 el proyecto con estas palabras: \\u00abJos\\u00e9 Antonio Abreu fund\\u00f3 El Sistema en 1975 para transformar a los ni\\u00f1os venezolanos, a trav\\u00e9s del aprendizaje musical y de su integraci\\u00f3n a las orquestas. Su audaz idea ha sembrado cientos de orquestas juveniles que hacen sus vidas felices. Su legado vive en los ni\\u00f1os alrededor del mundo. Pero su esfuerzo en Venezuela depende especialmente de la ayuda y el apoyo externos\\u00bb.<\\/p>\\n\\n\\n\\n<p>El Concurso Isang Yun es un concurso internacional de m\\u00fasica que se celebra anualmente en Tongyeong, Corea del Sur. Conmemora a Isang Yun (1917\\u20131995), un compositor coreano que naci\\u00f3 en Tongyeong y m\\u00e1s tarde se estableci\\u00f3 en Alemania. El concurso se estableci\\u00f3 en 2003 como el Concurso Internacional de M\\u00fasica de Gyeongnam, y se renombr\\u00f3 como Concurso ISANG YUN en 2008. Consiste en un \\u00abciclo\\u00bb de tres a\\u00f1os, donde cada a\\u00f1o, o \\u00abedici\\u00f3n\\u00bb, consta de un instrumento diferente en la rotaci\\u00f3n: violonchelo, piano y viol\\u00edn, refiere la nota.<\\/p>\\n\\n\\n\\n<p>Cada edici\\u00f3n para considerar a las figuras especiales de influencia mundial, tambi\\u00e9n cumple un ciclo de tres a\\u00f1os para consideraci\\u00f3n de los postulantes, las rondas de eliminaci\\u00f3n, la examinaci\\u00f3n del jurado. La m\\u00e1s reciente recibi\\u00f3 todas las candidaturas en el a\\u00f1o 2017, \\u00faltima premiaci\\u00f3n del concurso, siendo en este 2020 otorgados los reconocimientos correspondientes.<\\/p>\\n\\n\\n\\n<p>Este nuevo reconocimiento al Maestro Jos\\u00e9 Antonio Abreu compromete la acci\\u00f3n de nuestra instituci\\u00f3n para mantener viva y en crecimiento sostenido su obra a trav\\u00e9s del Sistema Nacional de Orquestas y Coros Juveniles e Infantiles de Venezuela, cuyo \\u00f3rgano rector es la Fundaci\\u00f3n Musical Sim\\u00f3n Bol\\u00edvar, adscrita al Ministerio del Poder Popular para la Presidencia y Seguimiento de la Gesti\\u00f3n de Gobierno de la Rep\\u00fablica Bolivariana de Venezuela.<\\/p>\\n","protected":false,"gt_translate_keys":[{"key":"rendered","format":"html"}]},"excerpt":{"rendered":"<p>Abreu fund\\u00f3 El Sistema en 1975 para transformar a los ni\\u00f1os venezolanos con la m\\u00fasica<\\/p>\\n","protected":false,"gt_translate_keys":[{"key":"rendered","format":"html"}]},"author":236,"featured_media":2156695,"comment_status":"open","ping_status":"closed","sticky":false,"template":"","format":"standard","meta":{"spay_emai ...

# %%
crawler.parse(response)

#crawler.query_extract_all_href

# %%
crawler.all_json_to_send
# Out:
# [{'url': 'http://ultimasnoticias.com.ve/?p=2156682',
#   'title': 'Conceden premio a la trayectoria del maestro José Antonio Abreu',
#   'date': '2020-10-12T18:49:55'},
#  {'url': 'http://ultimasnoticias.com.ve/?p=2156680',
#   'title': 'Invitan a iribarrenses a participar en ruta del reciclaje',
#   'date': '2020-10-12T18:49:47'},
#  {'url': 'http://ultimasnoticias.com.ve/?p=2156673',
#   'title': '500 jóvenes supervisan distribución de combustible en Caracas',
#   'date': '2020-10-12T18:39:40'},
#  {'url': 'http://ultimasnoticias.com.ve/?p=2156605',
#   'title': 'CNE inició auditoría de las maquinas de votación',
#   'date': '2020-10-12T17:46:38'},
#  {'url': 'http://ultimasnoticias.com.ve/?p=2156649',
#   'title': 'Yaracuy debate Ley Antibloqueo en asambleas populares',
#   'date': '2020-10-12T17:28:08'},
#  {'url': 'http://ultimasnoticias.com.ve/?p=2156636',
#   'title': 'Comando del GPP: Ley antibloqueo es un arma de soberanía popular',
#   'date': '2020-10-12T17:12:52'},
#  {'url': 'http://ultimasnoticias.com.ve/?p=2156640',
#   'title': 'Defensoría del Pueblo reconoce el trabajo en DDHH de pueblos indígenas',
#   'date': '2020-10-12T16:46:56'},
#  {'url': 'http://ultimasnoticias.com.ve/?p=2156634',
#   'title': 'La ONU pide nuevo impulso para un alto al fuego global',
#   'date': '2020-10-12T16:15:59'},
#  {'url': 'http://ultimasnoticias.com.ve/?p=2156633',
#   'title': 'Quino',
#   'date': '2020-10-12T16:13:12'},
#  {'url': 'http://ultimasnoticias.com.ve/?p=2156620',
#   'title': 'Esquema de flexibilización plus reactivó más del 80 % de la economía',
#   'date': '2020-10-12T15:56:06'}]

# %% [markdown]
# ### 4. Testing

# %%
#el crawler debe devolver una lista no vacia
assert(len(crawler.all_json_to_send)>0)

# %%
#lo que devuelve el crawler deben ser URLs correctas
assert validators.url(crawler.all_json_to_send[0]["url"])

# %% [markdown]
# ## Parte 2: Scraping

# %% [markdown]
# ### 1. URL _seed_

# %%
SEED_SCRAP = crawler.all_json_to_send[0]["url"]

# %% [markdown]
# ### 2. Class _Scraper_

# %%
QUERY_CONTENT =  "//div[@class='elementor-widget-container']//p"

# %%
DATE = crawler.all_json_to_send[0]["date"]
TITLE = crawler.all_json_to_send[0]["title"]

# %%
def validate_stripped(stripped_html_tags):
    
    notValid = [
        'Enlaces patrocinados',
        'Últimas Noticias también en tu correo',
        'Suscríbete',
        'Pronto recibirás el newsletter en tu correo',
        'Redacción',
        'Privacidad']
    
    if stripped_html_tags in notValid:
        return False
    else:
        return True

# %%
class Scraper:
    
    USER_AGENT_LIST = [
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1",
        "Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24"
    ]


    query_extract_text =  QUERY_CONTENT

    news_title = TITLE
    date = DATE

    def _init_(self):
        pass
    
    

    def clean_text(self, html_text):
        text_without_tags = w3lib.html.remove_tags(html_text)
        text_without_escape_chars = w3lib.html.replace_escape_chars(text_without_tags)
        text_without_escape_chars = html.unescape(text_without_escape_chars)
        text_without_whitespace = text_without_escape_chars.strip()
        return text_without_whitespace

    def replace_month_name_to_number(self,date_string):
        lower_string = date_string.lower()
        for month_id in range(1, 13):
            if(lower_string.find(calendar.month_name[month_id].lower())!=-1):
                if(month_id>=10):
                    return (lower_string.replace(calendar.month_name[month_id].lower(),str(month_id)))
                else:
                    return (lower_string.replace(calendar.month_name[month_id].lower(),"0"+str(month_id)))
            if(lower_string.find(calendar.month_abbr[month_id].lower())!=-1):
                if(month_id>=10):
                    return (lower_string.replace(calendar.month_abbr[month_id].lower(),str(month_id)))
                else:
                    return (lower_string.replace(calendar.month_abbr[month_id].lower(),"0"+str(month_id)))
                    
    #Se puede modificar
    def format_date(self,date):
        date = date.split("T")[0]
        return(date)

    #Se puede modificar
    def parse(self, response):
        self.news_text = []
        self.message_to_send = []
        self.scraped_url = response.url

        self.news_title = self.clean_text(self.news_title)
        self.date = self.clean_text(self.date)
        self.date = self.format_date(self.date)
        
        news_text_extracted_response = response.html.xpath(self.query_extract_text)
        for part_of_body in news_text_extracted_response:
            stripped_html_tags = w3lib.html.remove_tags(part_of_body.text)
            print(stripped_html_tags)
            
            valid_stripped = validate_stripped(stripped_html_tags)
            
            if(valid_stripped):
                self.news_text.append(stripped_html_tags)

    def start_request(self,url):
        headers = {'user-agent':random.choice(self.USER_AGENT_LIST) }
        session = HTMLSession()
        response = session.get(url,headers=headers)        
        return response

# %% [markdown]
# ### 3. Scraping

# %%
scraper = Scraper()
response =scraper.start_request(SEED_SCRAP)

# %%
scraper.parse(response)
# Out:
# Este domingo la prestigiosa organización surcoreana, Isang Yun, anunció el veredicto que este año 2020 concede el reconocimiento especial a la figura del fundador de El Sistema, el maestro venezolano, José A Abreu, destacando su vida y su legado educativo, el cual «vive en los niños alrededor del mundo».
# La fundación que desde el año 2003 organiza una importante competencia musical, destacó la labor realizada por el maestro Abreu, tras su paso como director, pianista, economista y educador venezolano, creador de El Sistema, está destinado a apoyar los proyectos de nuestra institución a través de la Unesco en Nueva York, reseña nota de prensa.
# Dicha postulación se presentó el proyecto con estas palabras: «José Antonio Abreu fundó El Sistema en 1975 para transformar a los niños venezolanos, a través del aprendizaje musical y de su integración a las orquestas. Su audaz idea ha sembrado cientos de orquestas juveniles que hacen sus vidas felices. Su legado vive en los niños alrededor del mundo. Pero su esfuerzo en Venezuela depende especialmente de la ayuda y el apoyo externos».
# El Concurso Isang Yun es un concurso internacional de música que se celebra anualmente en Tongyeong, Corea del Sur. Conmemora a Isang Yun (1917–1995), un compositor coreano que nació en Tongyeong y más tarde se estableció en Alemania. El concurso se estableció en 2003 como el Concurso Internacional de Música de Gyeongnam, y se renombró como Concurso ISANG YUN en 2008. Consiste en un «ciclo» de tres años, donde cada año, o «edición», consta de un instrumento diferente en la rotación: violonchelo, piano y violín, refiere la nota.
# Cada edición para considerar a las figuras especiales de influencia mundial, también cumple un ciclo de tres años para consideración de los postulantes, las rondas de eliminación, la examinación del jurado. La más reciente recibió todas las candidaturas en el año 2017, última premiación del concurso, siendo en este 2020 otorgados los reconocimientos correspondientes.
# Este nuevo reconocimiento al Maestro José Antonio Abreu compromete la acción de nuestra institución para mantener viva y en crecimiento sostenido su obra a través del Sistema Nacional de Orquestas y Coros Juveniles e Infantiles de Venezuela, cuyo órgano rector es la Fundación Musical Simón Bolívar, adscrita al Ministerio del Poder Popular para la Presidencia y Seguimiento de la Gestión de Gobierno de la República Bolivariana de Venezuela.
# Enlaces patrocinados
# Últimas Noticias también en tu correo
# Suscríbete
# Pronto recibirás el newsletter en tu correo
# Redacción
# Privacidad

# %%
scraper.news_title
# Out:
# 'Conceden premio a la trayectoria del maestro José Antonio Abreu'

# %%
scraper.date
# Out:
# '2020-10-12'

# %%
scraper.news_text
# Out:
# ['Este domingo la prestigiosa organización surcoreana, Isang Yun, anunció el veredicto que este año 2020 concede el reconocimiento especial a la figura del fundador de El Sistema, el maestro venezolano, José A Abreu, destacando su vida y su legado educativo, el cual «vive en los niños alrededor del mundo».',
#  'La fundación que desde el año 2003 organiza una importante competencia musical, destacó la labor realizada por el maestro Abreu, tras su paso como director, pianista, economista y educador venezolano, creador de El Sistema, está destinado a apoyar los proyectos de nuestra institución a través de la Unesco en Nueva York, reseña nota de prensa.',
#  'Dicha postulación se presentó el proyecto con estas palabras: «José Antonio Abreu fundó El Sistema en 1975 para transformar a los niños venezolanos, a través del aprendizaje musical y de su integración a las orquestas. Su audaz idea ha sembrado cientos de orquestas juveniles que hacen sus vidas felices. Su legado vive en los niños alrededor del mundo. Pero su esfuerzo en Venezuela depende especialmente de la ayuda y el apoyo externos».',
#  'El Concurso Isang Yun es un concurso internacional de música que se celebra anualmente en Tongyeong, Corea del Sur. Conmemora a Isang Yun (1917–1995), un compositor coreano que nació en Tongyeong y más tarde se estableció en Alemania. El concurso se estableció en 2003 como el Concurso Internacional de Música de Gyeongnam, y se renombró como Concurso ISANG YUN en 2008. Consiste en un «ciclo» de tres años, donde cada año, o «edición», consta de un instrumento diferente en la rotación: violonchelo, piano y violín, refiere la nota.',
#  'Cada edición para considerar a las figuras especiales de influencia mundial, también cumple un ciclo de tres años para consideración de los postulantes, las rondas de eliminación, la examinación del jurado. La más reciente recibió todas las candidaturas en el año 2017, última premiación del concurso, siendo en este 2020 otorgados los reconocimientos correspondientes.',
#  'Este nuevo reconocimiento al Maestro José Antonio Abreu compromete la acción de nuestra institución para mantener viva y en crecimiento sostenido su obra a través del Sistema Nacional de Orquestas y Coros Juveniles e Infantiles de Venezuela, cuyo órgano rector es la Fundación Musical Simón Bolívar, adscrita al Ministerio del Poder Popular para la Presidencia y Seguimiento de la Gestión de Gobierno de la República Bolivariana de Venezuela.']

# %% [markdown]
# ### 4. Testing

# %%
# Una función que verifica que las fechas tienen el formato correcto YYYY-MM-DD
def validate(date_text):
    try:
        datetime.datetime.strptime(date_text, "%Y-%m-%d")
        return True
    except:
        print("La fecha no tiene el formato correcto, año-mes-dia")
        return False

# %%
#Verificamos que el scraper devuelve algo y que las fechas tienen un formato correcto
assert(len(scraper.news_title)>0)
assert(len(scraper.news_text)>0)
assert(validate(scraper.date))
