# %%
import json
import w3lib.html
import random
import os
import datetime
import requests
import string
import calendar
import html
import locale 
import validators
from requests_html import HTML
from requests_html import HTMLSession

# %% [markdown]
# ## Crawler

# %%
SEED_CRAWL = 'https://globalnews.ca/wp-json/wp/v2/posts'

# %%
class Crawler:
    
    USER_AGENT_LIST = [
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1",
        "Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24"
]

    #query_extract_all_href=QUERY_URL

    all_json_to_send = []
    
    def _init_(self):
        pass
    
    def parse(self, response):
        ''' do something with this parser '''
        self.all_extracted_href = []
        json_data = json.loads(response.html.html)
        for url_data in json_data:
           
            json_to_send = {}
            json_to_send["url"] = url_data["guid"]["rendered"]
            json_to_send["title"] = url_data["title"]["rendered"]
            json_to_send["date"] = url_data["date_gmt"]
            self.all_json_to_send.append(json_to_send)      
                     

    def start_request(self,url,header=dict()):
        session = HTMLSession()
        header['user-agent'] = random.choice(self.USER_AGENT_LIST)
        response = session.get(url)  
        return response
    
    def get_number_of_pages(self,url,header=dict()):
        session = HTMLSession()
        header['user-agent'] = random.choice(self.USER_AGENT_LIST)
        response = session.get(url)  
        return response.headers['X-WP-TotalPages']

# %%
crawler = Crawler()
# Obtener el numero de paginas
number_of_pages = crawler.get_number_of_pages(SEED_CRAWL)
print(SEED_CRAWL, number_of_pages)
# Out:
# https://globalnews.ca/wp-json/wp/v2/posts 78848

# %%
all_data_crawler = []

# %%
number_of_pages = 10
for number_of_page in range(1, number_of_pages):
    response = crawler.start_request(SEED_CRAWL+'?page='+str(number_of_page))
    print('Se obtuvo la pagina '+str(number_of_page))
    crawler.parse(response)
    data_crawler = crawler.all_json_to_send
    all_data_crawler = all_data_crawler + data_crawler
# Out:
# Se obtuvo la pagina 1
# Se obtuvo la pagina 2
# Se obtuvo la pagina 3
# Se obtuvo la pagina 4
# Se obtuvo la pagina 5
# Se obtuvo la pagina 6
# Se obtuvo la pagina 7
# Se obtuvo la pagina 8
# Se obtuvo la pagina 9

# %%
all_data_crawler
# Out:
# [{'url': 'https://globalnews.ca/?p=7511016',
#   'title': 'COMMENTARY: Not even SARS could prepare the hospitality industry for COVID-19',
#   'date': '2020-12-13T14:00:19'},
#  {'url': 'https://globalnews.ca?p=7519153&#038;preview=true&#038;preview_id=7519153',
#   'title': 'Trucks carrying 1st coronavirus vaccines in U.S. prepare to depart',
#   'date': '2020-12-13T13:29:42'},
#  {'url': 'https://globalnews.ca/?p=7519147',
#   'title': 'A look at Canadian peacekeeping 25 years after Rwanda',
#   'date': '2020-12-13T13:01:12'},
#  {'url': 'https://globalnews.ca?p=7519143&#038;preview=true&#038;preview_id=7519143',
#   'title': 'Some older Canadians decide to spend winter in Florida despite coronavirus pandemic',
#   'date': '2020-12-13T12:34:13'},
#  {'url': 'https://globalnews.ca?p=7519138&#038;preview=true&#038;preview_id=7519138',
#   'title': 'Coronavirus: Germany tightens lockdown restrictions as cases rise',
#   'date': '2020-12-13T12:18:26'},
#  {'url': 'https://globalnews.ca/?p=7519135',
#   'title': 'Post-Brexit trade deal talks will continue, U.K., European Union officials say',
#   'date': '2020-12-13T12:06:21'},
#  {'url': 'https://globalnews.ca/?p=7499917',
#   'title': 'The best morning and night time routines',
#   'date': '2020-12-13T11:00:42'},
#  {'url': 'https://globalnews.ca/?p=7512918',
#   'title': 'Coronavirus: Psychologists say to keep your family&#8217;s mental health in mind during the holidays',
#   'date': '2020-12-13T11:00:30'},
#  {'url': 'https://globalnews.ca/?p=7519092',
#   'title': '&#8216;SNL&#8217; cold open spoofs CNN interview with Fauci, Birx on coronavirus vaccine rollout',
#   'date': '2020-12-13T05:20:42'},
#  {'url': 'https://globalnews.ca/?p=7519057',
#   'title': 'Calgary fire crews battle apartment blaze',
#   'date': '2020-12-13T03:46:19'},
#  {'url': 'https://globalnews.ca/?p=7511016',
#   'title': 'COMMENTARY: Not even SARS could prepare the hospitality industry for COVID-19',
#   'date': '2020-12-13T14:00:19'},
#  {'url': 'https://globalnews.ca?p=7519153&#038;preview=true&#038;preview_id=7519153',
#   'title': 'Trucks carrying 1st coronavirus vaccines in U.S. prepare to depart',
#   'date': '2020-12-13T13:29:42'},
#  {'url': 'https://globalnews.ca/?p=7519147',
#   'title': 'A look at Canadian peacekeeping 25 years after Rwanda',
#   'date': '2020-12-13T13:01:12'},
#  {'url': 'https://globalnews.ca?p=7519143&#038;preview=true&#038;preview_id=7519143',
#   'title': 'Some older Canadians decide to spend winter in Florida despite coronavirus pandemic',
#   'date': '2020-12-13T12:34:13'},
#  {'url': 'https://globalnews.ca?p=7519138&#038;preview=true&#038;preview_id=7519138',
#   'title': 'Coronavirus: Germany tightens lockdown restrictions as cases rise',
#   'date': '2020-12-13T12:18:26'},
#  {'url': 'https://globalnews.ca/?p=7519135',
#   'title': 'Post-Brexit trade deal talks will continue, U.K., European Union officials say',
#   'date': '2020-12-13T12:06:21'},
#  {'url': 'https://globalnews.ca/?p=7499917',
#   'title': 'The best morning and night time routines',
#   'date': '2020-12-13T11:00:42'},
#  {'url': 'https://globalnews.ca/?p=7512918',
#   'title': 'Coronavirus: Psychologists say to keep your family&#8217;s mental health in mind during the holidays',
#   'date': '2020-12-13T11:00:30'},
#  {'url': 'https://globalnews.ca/?p=7519092',
#   'title': '&#8216;SNL&#8217; cold open spoofs CNN interview with Fauci, Birx on coronavirus vaccine rollout',
#   'date': '2020-12-13T05:20:42'},
#  {'url': 'https://globalnews.ca/?p=7519057',
#   'title': 'Calgary fire crews battle apartment blaze',
#   'date': '2020-12-13T03:46:19'},
#  {'url': 'https://globalnews.ca/?p=7519065',
#   'title': '2 people killed, 1 person taken to hospital after Calgary collision, ASIRT investigating',
#   'date': '2020-12-13T03:36:58'},
#  {'url': 'https://globalnews.ca/?p=7518910',
#   'title': 'Fraser Health called Grinches for COVID-19 care home decoration rules',
#   'date': '2020-12-13T02:27:18'},
#  {'url': 'https://globalnews.ca/?p=7518895',
#   'title': 'Calgary city councillors to hear update on investigation into council expense policies',
#   'date': '2020-12-13T02:22:56'},
#  {'url': 'https://globalnews.ca/?p=7518983',
#   'title': 'Ontario COVID-19 ICU cases surpass 250, as additional lockdowns are set to be rolled out',
#   'date': '2020-12-13T02:22:30'},
#  {'url': 'https://globalnews.ca/?p=7518710',
#   'title': 'Calgary&#8217;s Olympic Plaza temporarily closed due to COVID-19 protest',
#   'date': '2020-12-13T01:56:28'},
#  {'url': 'https://globalnews.ca/?p=7518956',
#   'title': 'Hazardous construction material illegally dumped in north Kelowna neighbourhood: task force',
#   'date': '2020-12-13T01:32:55'},
#  {'url': 'http://globalnews.ca/?p=1148831',
#   'title': 'WATCH: Global National &#8211; December 12',
#   'date': '2020-12-13T01:00:05'},
#  {'url': 'https://globalnews.ca/?p=7514088',
#   'title': 'Stolen glow-in-the-dark equipment led to arrests: Saskatchewan fire chief',
#   'date': '2020-12-13T00:53:51'},
#  {'url': 'https://globalnews.ca?p=7518768&#038;preview=true&#038;preview_id=7518768',
#   'title': 'Health Canada warns people allergic to COVID-19 vaccine ingredients as cases surpass 450K',
#   'date': '2020-12-13T00:52:01'},
#  {'url': 'https://globalnews.ca/?p=7518955',
#   'title': 'Volunteers use flying flamethrower drone to incinerate wasp nests in China',
#   'date': '2020-12-13T00:50:09'},
#  {'url': 'https://globalnews.ca/?p=7511016',
#   'title': 'COMMENTARY: Not even SARS could prepare the hospitality industry for COVID-19',
#   'date': '2020-12-13T14:00:19'},
#  {'url': 'https://globalnews.ca?p=7519153&#038;preview=true&#038;preview_id=7519153',
#   'title': 'Trucks carrying 1st coronavirus vaccines in U.S. prepare to depart',
#   'date': '2020-12-13T13:29:42'},
#  {'url': 'https://globalnews.ca/?p=7519147',
#   'title': 'A look at Canadian peacekeeping 25 years after Rwanda',
#   'date': '2020-12-13T13:01:12'},
#  {'url': 'https://globalnews.ca?p=7519143&#038;preview=true&#038;preview_id=7519143',
#   'title': 'Some older Canadians decide to spend winter in Florida despite coronavirus pandemic',
#   'date': '2020-12-13T12:34:13'},
#  {'url': 'https://globalnews.ca?p=7519138&#038;preview=true&#038;preview_id=7519138',
#   'title': 'Coronavirus: Germany tightens lockdown restrictions as cases rise',
#   'date': '2020-12-13T12:18:26'},
#  {'url': 'https://globalnews.ca/?p=7519135',
#   'title': 'Post-Brexit trade deal talks will continue, U.K., European Union officials say',
#   'date': '2020-12-13T12:06:21'},
#  {'url': 'https://globalnews.ca/?p=7499917',
#   'title': 'The best morning and night time routines',
#   'date': '2020-12-13T11:00:42'},
#  {'url': 'https://globalnews.ca/?p=7512918',
#   'title': 'Coronavirus: Psychologists say to keep your family&#8217;s mental health in mind during the holidays',
#   'date': '2020-12-13T11:00:30'},
#  {'url': 'https://globalnews.ca/?p=7519092',
#   'title': '&#8216;SNL&#8217; cold open spoofs CNN interview with Fauci, Birx on coronavirus vaccine rollout',
#   'date': '2020-12-13T05:20:42'},
#  {'url': 'https://globalnews.ca/?p=7519057',
#   'title': 'Calgary fire crews battle apartment blaze',
#   'date': '2020-12-13T03:46:19'},
#  {'url': 'https://globalnews.ca/?p=7519065',
#   'title': '2 people killed, 1 person taken to hospital after Calgary collision, ASIRT investigating',
#   'date': '2020-12-13T03:36:58'},
#  {'url': 'https://globalnews.ca/?p=7518910',
#   'title': 'Fraser Health called Grinches for COVID-19 care home decoration rules',
#   'date': '2020-12-13T02:27:18'},
#  {'url': 'https://globalnews.ca/?p=7518895',
#   'title': 'Calgary city councillors to hear update on investigation into council expense policies',
#   'date': '2020-12-13T02:22:56'},
#  {'url': 'https://globalnews.ca/?p=7518983',
#   'title': 'Ontario COVID-19 ICU cases surpass 250, as additional lockdowns are set to be rolled out',
#   'date': '2020-12-13T02:22:30'},
#  {'url': 'https://globalnews.ca/?p=7518710',
#   'title': 'Calgary&#8217;s Olympic Plaza temporarily closed due to COVID-19 protest',
#   'date': '2020-12-13T01:56:28'},
#  {'url': 'https://globalnews.ca/?p=7518956',
#   'title': 'Hazardous construction material illegally dumped in north Kelowna neighbourhood: task force',
#   'date': '2020-12-13T01:32:55'},
#  {'url': 'http://globalnews.ca/?p=1148831',
#   'title': 'WATCH: Global National &#8211; December 12',
#   'date': '2020-12-13T01:00:05'},
#  {'url': 'https://globalnews.ca/?p=7514088',
#   'title': 'Stolen glow-in-the-dark equipment led to arrests: Saskatchewan fire chief',
#   'date': '2020-12-13T00:53:51'},
#  {'url': 'https://globalnews.ca?p=7518768&#038;preview=true&#038;preview_id=7518768',
#   'title': 'Health Canada warns people allergic to COVID-19 vaccine ingredients as cases surpass 450K',
#   'date': '2020-12-13T00:52:01'},
#  {'url': 'https://globalnews.ca/?p=7518955',
#   'title': 'Volunteers use flying flamethrower drone to incinerate wasp nests in China',
#   'date': '2020-12-13T00:50:09'},
#  {'url': 'https://globalnews.ca/?p=7518681',
#   'title': 'The uprising of India&#8217;s farmers: The significance and history behind the worldwide protests',
#   'date': '2020-12-13T00:26:18'},
#  {'url': 'https://globalnews.ca?p=7518760&#038;preview=true&#038;preview_id=7518760',
#   'title': 'Containing COVID-19 outbreak to single B.C. mink farm essential, say experts',
#   'date': '2020-12-12T23:51:52'},
#  {'url': 'https://globalnews.ca/?p=7518882',
#   'title': 'Coronavirus: Hundreds attend anti-restriction rally in downtown Kelowna',
#   'date': '2020-12-12T23:44:11'},
#  {'url': 'https://globalnews.ca/?p=7518579',
#   'title': 'Quebec government to fund $600,000 for Montreal Indigenous shelter&#8217;s relocation',
#   'date': '2020-12-12T23:26:15'},
#  {'url': 'https://globalnews.ca/?p=7518567',
#   'title': 'Calgary pools close as councillor seeks options for struggling inner city aquatic centre',
#   'date': '2020-12-12T23:21:00'},
#  {'url': 'https://globalnews.ca/?p=7518625',
#   'title': 'Calgary, Edmonton protesters rally against COVID-19 measures as Alberta adds 1,590 new cases',
#   'date': '2020-12-12T22:59:38'},
#  {'url': 'https://globalnews.ca/?p=7518754',
#   'title': 'Recovery of body from southwest, London, Ont., building collapse difficult due to &#8216;unstable structure&#8217;',
#   'date': '2020-12-12T22:40:27'},
#  {'url': 'https://globalnews.ca/?p=7518835',
#   'title': 'Charley Pride, country music legend, dies from coronavirus at 86',
#   'date': '2020-12-12T22:29:30'},
#  {'url': 'https://globalnews.ca/?p=7518791',
#   'title': '2 arrested for illegal night hunting with stolen firearm in Manitoba',
#   'date': '2020-12-12T22:13:14'},
#  {'url': 'https://globalnews.ca/?p=7518758',
#   'title': 'Regina family collecting, donating gifts to those in need over the holidays',
#   'date': '2020-12-12T22:10:53'},
#  {'url': 'https://globalnews.ca/?p=7511016',
#   'title': 'COMMENTARY: Not even SARS could prepare the hospitality industry for COVID-19',
#   'date': '2020-12-13T14:00:19'},
#  {'url': 'https://globalnews.ca?p=7519153&#038;preview=true&#038;preview_id=7519153',
#   'title': 'Trucks carrying 1st coronavirus vaccines in U.S. prepare to depart',
#   'date': '2020-12-13T13:29:42'},
#  {'url': 'https://globalnews.ca/?p=7519147',
#   'title': 'A look at Canadian peacekeeping 25 years after Rwanda',
#   'date': '2020-12-13T13:01:12'},
#  {'url': 'https://globalnews.ca?p=7519143&#038;preview=true&#038;preview_id=7519143',
#   'title': 'Some older Canadians decide to spend winter in Florida despite coronavirus pandemic',
#   'date': '2020-12-13T12:34:13'},
#  {'url': 'https://globalnews.ca?p=7519138&#038;preview=true&#038;preview_id=7519138',
#   'title': 'Coronavirus: Germany tightens lockdown restrictions as cases rise',
#   'date': '2020-12-13T12:18:26'},
#  {'url': 'https://globalnews.ca/?p=7519135',
#   'title': 'Post-Brexit trade deal talks will continue, U.K., European Union officials say',
#   'date': '2020-12-13T12:06:21'},
#  {'url': 'https://globalnews.ca/?p=7499917',
#   'title': 'The best morning and night time routines',
#   'date': '2020-12-13T11:00:42'},
#  {'url': 'https://globalnews.ca/?p=7512918',
#   'title': 'Coronavirus: Psychologists say to keep your family&#8217;s mental health in mind during the holidays',
#   'date': '2020-12-13T11:00:30'},
#  {'url': 'https://globalnews.ca/?p=7519092',
#   'title': '&#8216;SNL&#8217; cold open spoofs CNN interview with Fauci, Birx on coronavirus vaccine rollout',
#   'date': '2020-12-13T05:20:42'},
#  {'url': 'https://globalnews.ca/?p=7519057',
#   'title': 'Calgary fire crews battle apartment blaze',
#   'date': '2020-12-13T03:46:19'},
#  {'url': 'https://globalnews.ca/?p=7519065',
#   'title': '2 people killed, 1 person taken to hospital after Calgary collision, ASIRT investigating',
#   'date': '2020-12-13T03:36:58'},
#  {'url': 'https://globalnews.ca/?p=7518910',
#   'title': 'Fraser Health called Grinches for COVID-19 care home decoration rules',
#   'date': '2020-12-13T02:27:18'},
#  {'url': 'https://globalnews.ca/?p=7518895',
#   'title': 'Calgary city councillors to hear update on investigation into council expense policies',
#   'date': '2020-12-13T02:22:56'},
#  {'url': 'https://globalnews.ca/?p=7518983',
#   'title': 'Ontario COVID-19 ICU cases surpass 250, as additional lockdowns are set to be rolled out',
#   'date': '2020-12-13T02:22:30'},
#  {'url': 'https://globalnews.ca/?p=7518710',
#   'title': 'Calgary&#8217;s Olympic Plaza temporarily closed due to COVID-19 protest',
#   'date': '2020-12-13T01:56:28'},
#  {'url': 'https://globalnews.ca/?p=7518956',
#   'title': 'Hazardous construction material illegally dumped in north Kelowna neighbourhood: task force',
#   'date': '2020-12-13T01:32:55'},
#  {'url': 'http://globalnews.ca/?p=1148831',
#   'title': 'WATCH: Global National &#8211; December 12',
#   'date': '2020-12-13T01:00:05'},
#  {'url': 'https://globalnews.ca/?p=7514088',
#   'title': 'Stolen glow-in-the-dark equipment led to arrests: Saskatchewan fire chief',
#   'date': '2020-12-13T00:53:51'},
#  {'url': 'https://globalnews.ca?p=7518768&#038;preview=true&#038;preview_id=7518768',
#   'title': 'Health Canada warns people allergic to COVID-19 vaccine ingredients as cases surpass 450K',
#   'date': '2020-12-13T00:52:01'},
#  {'url': 'https://globalnews.ca/?p=7518955',
#   'title': 'Volunteers use flying flamethrower drone to incinerate wasp nests in China',
#   'date': '2020-12-13T00:50:09'},
#  {'url': 'https://globalnews.ca/?p=7518681',
#   'title': 'The uprising of India&#8217;s farmers: The significance and history behind the worldwide protests',
#   'date': '2020-12-13T00:26:18'},
#  {'url': 'https://globalnews.ca?p=7518760&#038;preview=true&#038;preview_id=7518760',
#   'title': 'Containing COVID-19 outbreak to single B.C. mink farm essential, say experts',
#   'date': '2020-12-12T23:51:52'},
#  {'url': 'https://globalnews.ca/?p=7518882',
#   'title': 'Coronavirus: Hundreds attend anti-restriction rally in downtown Kelowna',
#   'date': '2020-12-12T23:44:11'},
#  {'url': 'https://globalnews.ca/?p=7518579',
#   'title': 'Quebec government to fund $600,000 for Montreal Indigenous shelter&#8217;s relocation',
#   'date': '2020-12-12T23:26:15'},
#  {'url': 'https://globalnews.ca/?p=7518567',
#   'title': 'Calgary pools close as councillor seeks options for struggling inner city aquatic centre',
#   'date': '2020-12-12T23:21:00'},
#  {'url': 'https://globalnews.ca/?p=7518625',
#   'title': 'Calgary, Edmonton protesters rally against COVID-19 measures as Alberta adds 1,590 new cases',
#   'date': '2020-12-12T22:59:38'},
#  {'url': 'https://globalnews.ca/?p=7518754',
#   'title': 'Recovery of body from southwest, London, Ont., building collapse difficult due to &#8216;unstable structure&#8217;',
#   'date': '2020-12-12T22:40:27'},
#  {'url': 'https://globalnews.ca/?p=7518835',
#   'title': 'Charley Pride, country music legend, dies from coronavirus at 86',
#   'date': '2020-12-12T22:29:30'},
#  {'url': 'https://globalnews.ca/?p=7518791',
#   'title': '2 arrested for illegal night hunting with stolen firearm in Manitoba',
#   'date': '2020-12-12T22:13:14'},
#  {'url': 'https://globalnews.ca/?p=7518758',
#   'title': 'Regina family collecting, donating gifts to those in need over the holidays',
#   'date': '2020-12-12T22:10:53'},
#  {'url': 'https://globalnews.ca/?p=7518751',
#   'title': 'Hunter Biden subpoena seeks documents on dealings with former employer Burisma',
#   'date': '2020-12-12T21:46:20'},
#  {'url': 'https://globalnews.ca/?p=7518713',
#   'title': 'B.C. airline announces direct flights between Penticton and Vancouver',
#   'date': '2020-12-12T21:35:13'},
#  {'url': 'https://globalnews.ca/?p=7518676',
#   'title': 'New Out of the Cold shelter set to open Saturday night',
#   'date': '2020-12-12T21:15:25'},
#  {'url': 'https://globalnews.ca/?p=7518259',
#   'title': 'Canada to challenge U.S. softwood lumber export duties through World Trade Organization',
#   'date': '2020-12-12T21:13:02'},
#  {'url': 'https://globalnews.ca/?p=7518155',
#   'title': 'Rally held to protest loss of jobs, quality care at Bowmanville retirement home',
#   'date': '2020-12-12T21:05:58'},
#  {'url': 'https://globalnews.ca/?p=7518599',
#   'title': 'Pro, anti-Trump demonstrators clash during rally in Washington',
#   'date': '2020-12-12T21:01:37'},
#  {'url': 'https://globalnews.ca/?p=7518631',
#   'title': 'RCMP recommend charges against Chilliwack churches that broke COVID-19 restrictions',
#   'date': '2020-12-12T20:55:36'},
#  {'url': 'https://globalnews.ca/?p=7518653',
#   'title': 'Bailiff shot at while delivering court documents to Okotoks home: RCMP',
#   'date': '2020-12-12T20:30:12'},
#  {'url': 'https://globalnews.ca/?p=7518594',
#   'title': 'Saskatchewan reports 11 deaths, 274 new cases of coronavirus',
#   'date': '2020-12-12T20:29:11'},
#  {'url': 'https://globalnews.ca/?p=7518565',
#   'title': 'Coronavirus: With caseloads increasing, Interior Health urging residents to help limit spread',
#   'date': '2020-12-12T20:26:11'},
#  {'url': 'https://globalnews.ca/?p=7511016',
#   'title': 'COMMENTARY: Not even SARS could prepare the hospitality industry for COVID-19',
#   'date': '2020-12-13T14:00:19'},
#  {'url': 'https://globalnews.ca?p=7519153&#038;preview=true&#038;preview_id=7519153',
#   'title': 'Trucks carrying 1st coronavirus vaccines in U.S. prepare to depart',
#   'date': '2020-12-13T13:29:42'},
#  {'url': 'https://globalnews.ca/?p=7519147',
#   'title': 'A look at Canadian peacekeeping 25 years after Rwanda',
#   'date': '2020-12-13T13:01:12'},
#  {'url': 'https://globalnews.ca?p=7519143&#038;preview=true&#038;preview_id=7519143',
#   'title': 'Some older Canadians decide to spend winter in Florida despite coronavirus pandemic',
#   'date': '2020-12-13T12:34:13'},
#  {'url': 'https://globalnews.ca?p=7519138&#038;preview=true&#038;preview_id=7519138',
#   'title': 'Coronavirus: Germany tightens lockdown restrictions as cases rise',
#   'date': '2020-12-13T12:18:26'},
#  {'url': 'https://globalnews.ca/?p=7519135',
#   'title': 'Post-Brexit trade deal talks will continue, U.K., European Union officials say',
#   'date': '2020-12-13T12:06:21'},
#  {'url': 'https://globalnews.ca/?p=7499917',
#   'title': 'The best morning and night time routines',
#   'date': '2020-12-13T11:00:42'},
#  {'url': 'https://globalnews.ca/?p=7512918',
#   'title': 'Coronavirus: Psychologists say to keep your family&#8217;s mental health in mind during the holidays',
#   'date': '2020-12-13T11:00:30'},
#  {'url': 'https://globalnews.ca/?p=7519092',
#   'title': '&#8216;SNL&#8217; cold open spoofs CNN interview with Fauci, Birx on coronavirus vaccine rollout',
#   'date': '2020-12-13T05:20:42'},
#  {'url': 'https://globalnews.ca/?p=7519057',
#   'title': 'Calgary fire crews battle apartment blaze',
#   'date': '2020-12-13T03:46:19'},
#  {'url': 'https://globalnews.ca/?p=7519065',
#   'title': '2 people killed, 1 person taken to hospital after Calgary collision, ASIRT investigating',
#   'date': '2020-12-13T03:36:58'},
#  {'url': 'https://globalnews.ca/?p=7518910',
#   'title': 'Fraser Health called Grinches for COVID-19 care home decoration rules',
#   'date': '2020-12-13T02:27:18'},
#  {'url': 'https://globalnews.ca/?p=7518895',
#   'title': 'Calgary city councillors to hear update on investigation into council expense policies',
#   'date': '2020-12-13T02:22:56'},
#  {'url': 'https://globalnews.ca/?p=7518983',
#   'title': 'Ontario COVID-19 ICU cases surpass 250, as additional lockdowns are set to be rolled out',
#   'date': '2020-12-13T02:22:30'},
#  {'url': 'https://globalnews.ca/?p=7518710',
#   'title': 'Calgary&#8217;s Olympic Plaza temporarily closed due to COVID-19 protest',
#   'date': '2020-12-13T01:56:28'},
#  {'url': 'https://globalnews.ca/?p=7518956',
#   'title': 'Hazardous construction material illegally dumped in north Kelowna neighbourhood: task force',
#   'date': '2020-12-13T01:32:55'},
#  {'url': 'http://globalnews.ca/?p=1148831',
#   'title': 'WATCH: Global National &#8211; December 12',
#   'date': '2020-12-13T01:00:05'},
#  {'url': 'https://globalnews.ca/?p=7514088',
#   'title': 'Stolen glow-in-the-dark equipment led to arrests: Saskatchewan fire chief',
#   'date': '2020-12-13T00:53:51'},
#  {'url': 'https://globalnews.ca?p=7518768&#038;preview=true&#038;preview_id=7518768',
#   'title': 'Health Canada warns people allergic to COVID-19 vaccine ingredients as cases surpass 450K',
#   'date': '2020-12-13T00:52:01'},
#  {'url': 'https://globalnews.ca/?p=7518955',
#   'title': 'Volunteers use flying flamethrower drone to incinerate wasp nests in China',
#   'date': '2020-12-13T00:50:09'},
#  {'url': 'https://globalnews.ca/?p=7518681',
#   'title': 'The uprising of India&#8217;s farmers: The significance and history behind the worldwide protests',
#   'date': '2020-12-13T00:26:18'},
#  {'url': 'https://globalnews.ca?p=7518760&#038;preview=true&#038;preview_id=7518760',
#   'title': 'Containing COVID-19 outbreak to single B.C. mink farm essential, say experts',
#   'date': '2020-12-12T23:51:52'},
#  {'url': 'https://globalnews.ca/?p=7518882',
#   'title': 'Coronavirus: Hundreds attend anti-restriction rally in downtown Kelowna',
#   'date': '2020-12-12T23:44:11'},
#  {'url': 'https://globalnews.ca/?p=7518579',
#   'title': 'Quebec government to fund $600,000 for Montreal Indigenous shelter&#8217;s relocation',
#   'date': '2020-12-12T23:26:15'},
#  {'url': 'https://globalnews.ca/?p=7518567',
#   'title': 'Calgary pools close as councillor seeks options for struggling inner city aquatic centre',
#   'date': '2020-12-12T23:21:00'},
#  {'url': 'https://globalnews.ca/?p=7518625',
#   'title': 'Calgary, Edmonton protesters rally against COVID-19 measures as Alberta adds 1,590 new cases',
#   'date': '2020-12-12T22:59:38'},
#  {'url': 'https://globalnews.ca/?p=7518754',
#   'title': 'Recovery of body from southwest, London, Ont., building collapse difficult due to &#8216;unstable structure&#8217;',
#   'date': '2020-12-12T22:40:27'},
#  {'url': 'https://globalnews.ca/?p=7518835',
#   'title': 'Charley Pride, country music legend, dies from coronavirus at 86',
#   'date': '2020-12-12T22:29:30'},
#  {'url': 'https://globalnews.ca/?p=7518791',
#   'title': '2 arrested for illegal night hunting with stolen firearm in Manitoba',
#   'date': '2020-12-12T22:13:14'},
#  {'url': 'https://globalnews.ca/?p=7518758',
#   'title': 'Regina family collecting, donating gifts to those in need over the holidays',
#   'date': '2020-12-12T22:10:53'},
#  {'url': 'https://globalnews.ca/?p=7518751',
#   'title': 'Hunter Biden subpoena seeks documents on dealings with former employer Burisma',
#   'date': '2020-12-12T21:46:20'},
#  {'url': 'https://globalnews.ca/?p=7518713',
#   'title': 'B.C. airline announces direct flights between Penticton and Vancouver',
#   'date': '2020-12-12T21:35:13'},
#  {'url': 'https://globalnews.ca/?p=7518676',
#   'title': 'New Out of the Cold shelter set to open Saturday night',
#   'date': '2020-12-12T21:15:25'},
#  {'url': 'https://globalnews.ca/?p=7518259',
#   'title': 'Canada to challenge U.S. softwood lumber export duties through World Trade Organization',
#   'date': '2020-12-12T21:13:02'},
#  {'url': 'https://globalnews.ca/?p=7518155',
#   'title': 'Rally held to protest loss of jobs, quality care at Bowmanville retirement home',
#   'date': '2020-12-12T21:05:58'},
#  {'url': 'https://globalnews.ca/?p=7518599',
#   'title': 'Pro, anti-Trump demonstrators clash during rally in Washington',
#   'date': '2020-12-12T21:01:37'},
#  {'url': 'https://globalnews.ca/?p=7518631',
#   'title': 'RCMP recommend charges against Chilliwack churches that broke COVID-19 restrictions',
#   'date': '2020-12-12T20:55:36'},
#  {'url': 'https://globalnews.ca/?p=7518653',
#   'title': 'Bailiff shot at while delivering court documents to Okotoks home: RCMP',
#   'date': '2020-12-12T20:30:12'},
#  {'url': 'https://globalnews.ca/?p=7518594',
#   'title': 'Saskatchewan reports 11 deaths, 274 new cases of coronavirus',
#   'date': '2020-12-12T20:29:11'},
#  {'url': 'https://globalnews.ca/?p=7518565',
#   'title': 'Coronavirus: With caseloads increasing, Interior Health urging residents to help limit spread',
#   'date': '2020-12-12T20:26:11'},
#  {'url': 'https://globalnews.ca/?p=7518378',
#   'title': 'Death linked to long-term care home, 32 new coronavirus cases in London and Middlesex',
#   'date': '2020-12-12T20:23:55'},
#  {'url': 'https://globalnews.ca/?p=7518633',
#   'title': 'Walking bridge built after New Brunswick woman stranded when storm washed out bridge',
#   'date': '2020-12-12T20:17:45'},
#  {'url': 'https://globalnews.ca/?p=7518514',
#   'title': '19-year-old man shot dead in East Vancouver in city&#8217;s 18th homicide of 2020',
#   'date': '2020-12-12T20:04:29'},
#  {'url': 'https://globalnews.ca/?p=7518519',
#   'title': 'Regina police issue two &#8220;Freedom Rally&#8221; organizers $2,800 fines',
#   'date': '2020-12-12T20:04:12'},
#  {'url': 'https://globalnews.ca/?p=7518608',
#   'title': 'Toronto police bean-bag shooting during mental-health call prompts SIU investigation',
#   'date': '2020-12-12T19:54:50'},
#  {'url': 'https://globalnews.ca/?p=7518559',
#   'title': 'RCMP lay charges after organized crime bust in Halifax',
#   'date': '2020-12-12T19:42:49'},
#  {'url': 'https://globalnews.ca/?p=7518494',
#   'title': 'UPS shares &#8216;1st images&#8217; of coronavirus vaccine en route to Canada',
#   'date': '2020-12-12T19:42:44'},
#  {'url': 'https://globalnews.ca/?p=7518568',
#   'title': 'Calgary&#8217;s COVID-19 airport pilot program could expand to Edmonton',
#   'date': '2020-12-12T19:39:40'},
#  {'url': 'https://globalnews.ca/?p=7518455',
#   'title': 'N.B. government wage-freeze pitch &#8216;a slap in the face&#8217;: unions',
#   'date': '2020-12-12T19:33:48'},
#  {'url': 'https://globalnews.ca/?p=7518483',
#   'title': 'BC Ferries adds extra sailings, but passengers urged to avoid non-essential travel',
#   'date': '2020-12-12T19:09:20'},
#  {'url': 'https://globalnews.ca/?p=7511016',
#   'title': 'COMMENTARY: Not even SARS could prepare the hospitality industry for COVID-19',
#   'date': '2020-12-13T14:00:19'},
#  {'url': 'https://globalnews.ca?p=7519153&#038;preview=true&#038;preview_id=7519153',
#   'title': 'Trucks carrying 1st coronavirus vaccines in U.S. prepare to depart',
#   'date': '2020-12-13T13:29:42'},
#  {'url': 'https://globalnews.ca/?p=7519147',
#   'title': 'A look at Canadian peacekeeping 25 years after Rwanda',
#   'date': '2020-12-13T13:01:12'},
#  {'url': 'https://globalnews.ca?p=7519143&#038;preview=true&#038;preview_id=7519143',
#   'title': 'Some older Canadians decide to spend winter in Florida despite coronavirus pandemic',
#   'date': '2020-12-13T12:34:13'},
#  {'url': 'https://globalnews.ca?p=7519138&#038;preview=true&#038;preview_id=7519138',
#   'title': 'Coronavirus: Germany tightens lockdown restrictions as cases rise',
#   'date': '2020-12-13T12:18:26'},
#  {'url': 'https://globalnews.ca/?p=7519135',
#   'title': 'Post-Brexit trade deal talks will continue, U.K., European Union officials say',
#   'date': '2020-12-13T12:06:21'},
#  {'url': 'https://globalnews.ca/?p=7499917',
#   'title': 'The best morning and night time routines',
#   'date': '2020-12-13T11:00:42'},
#  {'url': 'https://globalnews.ca/?p=7512918',
#   'title': 'Coronavirus: Psychologists say to keep your family&#8217;s mental health in mind during the holidays',
#   'date': '2020-12-13T11:00:30'},
#  {'url': 'https://globalnews.ca/?p=7519092',
#   'title': '&#8216;SNL&#8217; cold open spoofs CNN interview with Fauci, Birx on coronavirus vaccine rollout',
#   'date': '2020-12-13T05:20:42'},
#  {'url': 'https://globalnews.ca/?p=7519057',
#   'title': 'Calgary fire crews battle apartment blaze',
#   'date': '2020-12-13T03:46:19'},
#  {'url': 'https://globalnews.ca/?p=7519065',
#   'title': '2 people killed, 1 person taken to hospital after Calgary collision, ASIRT investigating',
#   'date': '2020-12-13T03:36:58'},
#  {'url': 'https://globalnews.ca/?p=7518910',
#   'title': 'Fraser Health called Grinches for COVID-19 care home decoration rules',
#   'date': '2020-12-13T02:27:18'},
#  {'url': 'https://globalnews.ca/?p=7518895',
#   'title': 'Calgary city councillors to hear update on investigation into council expense policies',
#   'date': '2020-12-13T02:22:56'},
#  {'url': 'https://globalnews.ca/?p=7518983',
#   'title': 'Ontario COVID-19 ICU cases surpass 250, as additional lockdowns are set to be rolled out',
#   'date': '2020-12-13T02:22:30'},
#  {'url': 'https://globalnews.ca/?p=7518710',
#   'title': 'Calgary&#8217;s Olympic Plaza temporarily closed due to COVID-19 protest',
#   'date': '2020-12-13T01:56:28'},
#  {'url': 'https://globalnews.ca/?p=7518956',
#   'title': 'Hazardous construction material illegally dumped in north Kelowna neighbourhood: task force',
#   'date': '2020-12-13T01:32:55'},
#  {'url': 'http://globalnews.ca/?p=1148831',
#   'title': 'WATCH: Global National &#8211; December 12',
#   'date': '2020-12-13T01:00:05'},
#  {'url': 'https://globalnews.ca/?p=7514088',
#   'title': 'Stolen glow-in-the-dark equipment led to arrests: Saskatchewan fire chief',
#   'date': '2020-12-13T00:53:51'},
#  {'url': 'https://globalnews.ca?p=7518768&#038;preview=true&#038;preview_id=7518768',
#   'title': 'Health Canada warns people allergic to COVID-19 vaccine ingredients as cases surpass 450K',
#   'date': '2020-12-13T00:52:01'},
#  {'url': 'https://globalnews.ca/?p=7518955',
#   'title': 'Volunteers use flying flamethrower drone to incinerate wasp nests in China',
#   'date': '2020-12-13T00:50:09'},
#  {'url': 'https://globalnews.ca/?p=7518681',
#   'title': 'The uprising of India&#8217;s farmers: The significance and history behind the worldwide protests',
#   'date': '2020-12-13T00:26:18'},
#  {'url': 'https://globalnews.ca?p=7518760&#038;preview=true&#038;preview_id=7518760',
#   'title': 'Containing COVID-19 outbreak to single B.C. mink farm essential, say experts',
#   'date': '2020-12-12T23:51:52'},
#  {'url': 'https://globalnews.ca/?p=7518882',
#   'title': 'Coronavirus: Hundreds attend anti-restriction rally in downtown Kelowna',
#   'date': '2020-12-12T23:44:11'},
#  {'url': 'https://globalnews.ca/?p=7518579',
#   'title': 'Quebec government to fund $600,000 for Montreal Indigenous shelter&#8217;s relocation',
#   'date': '2020-12-12T23:26:15'},
#  {'url': 'https://globalnews.ca/?p=7518567',
#   'title': 'Calgary pools close as councillor seeks options for struggling inner city aquatic centre',
#   'date': '2020-12-12T23:21:00'},
#  {'url': 'https://globalnews.ca/?p=7518625',
#   'title': 'Calgary, Edmonton protesters rally against COVID-19 measures as Alberta adds 1,590 new cases',
#   'date': '2020-12-12T22:59:38'},
#  {'url': 'https://globalnews.ca/?p=7518754',
#   'title': 'Recovery of body from southwest, London, Ont., building collapse difficult due to &#8216;unstable structure&#8217;',
#   'date': '2020-12-12T22:40:27'},
#  {'url': 'https://globalnews.ca/?p=7518835',
#   'title': 'Charley Pride, country music legend, dies from coronavirus at 86',
#   'date': '2020-12-12T22:29:30'},
#  {'url': 'https://globalnews.ca/?p=7518791',
#   'title': '2 arrested for illegal night hunting with stolen firearm in Manitoba',
#   'date': '2020-12-12T22:13:14'},
#  {'url': 'https://globalnews.ca/?p=7518758',
#   'title': 'Regina family collecting, donating gifts to those in need over the holidays',
#   'date': '2020-12-12T22:10:53'},
#  {'url': 'https://globalnews.ca/?p=7518751',
#   'title': 'Hunter Biden subpoena seeks documents on dealings with former employer Burisma',
#   'date': '2020-12-12T21:46:20'},
#  {'url': 'https://globalnews.ca/?p=7518713',
#   'title': 'B.C. airline announces direct flights between Penticton and Vancouver',
#   'date': '2020-12-12T21:35:13'},
#  {'url': 'https://globalnews.ca/?p=7518676',
#   'title': 'New Out of the Cold shelter set to open Saturday night',
#   'date': '2020-12-12T21:15:25'},
#  {'url': 'https://globalnews.ca/?p=7518259',
#   'title': 'Canada to challenge U.S. softwood lumber export duties through World Trade Organization',
#   'date': '2020-12-12T21:13:02'},
#  {'url': 'https://globalnews.ca/?p=7518155',
#   'title': 'Rally held to protest loss of jobs, quality care at Bowmanville retirement home',
#   'date': '2020-12-12T21:05:58'},
#  {'url': 'https://globalnews.ca/?p=7518599',
#   'title': 'Pro, anti-Trump demonstrators clash during rally in Washington',
#   'date': '2020-12-12T21:01:37'},
#  {'url': 'https://globalnews.ca/?p=7518631',
#   'title': 'RCMP recommend charges against Chilliwack churches that broke COVID-19 restrictions',
#   'date': '2020-12-12T20:55:36'},
#  {'url': 'https://globalnews.ca/?p=7518653',
#   'title': 'Bailiff shot at while delivering court documents to Okotoks home: RCMP',
#   'date': '2020-12-12T20:30:12'},
#  {'url': 'https://globalnews.ca/?p=7518594',
#   'title': 'Saskatchewan reports 11 deaths, 274 new cases of coronavirus',
#   'date': '2020-12-12T20:29:11'},
#  {'url': 'https://globalnews.ca/?p=7518565',
#   'title': 'Coronavirus: With caseloads increasing, Interior Health urging residents to help limit spread',
#   'date': '2020-12-12T20:26:11'},
#  {'url': 'https://globalnews.ca/?p=7518378',
#   'title': 'Death linked to long-term care home, 32 new coronavirus cases in London and Middlesex',
#   'date': '2020-12-12T20:23:55'},
#  {'url': 'https://globalnews.ca/?p=7518633',
#   'title': 'Walking bridge built after New Brunswick woman stranded when storm washed out bridge',
#   'date': '2020-12-12T20:17:45'},
#  {'url': 'https://globalnews.ca/?p=7518514',
#   'title': '19-year-old man shot dead in East Vancouver in city&#8217;s 18th homicide of 2020',
#   'date': '2020-12-12T20:04:29'},
#  {'url': 'https://globalnews.ca/?p=7518519',
#   'title': 'Regina police issue two &#8220;Freedom Rally&#8221; organizers $2,800 fines',
#   'date': '2020-12-12T20:04:12'},
#  {'url': 'https://globalnews.ca/?p=7518608',
#   'title': 'Toronto police bean-bag shooting during mental-health call prompts SIU investigation',
#   'date': '2020-12-12T19:54:50'},
#  {'url': 'https://globalnews.ca/?p=7518559',
#   'title': 'RCMP lay charges after organized crime bust in Halifax',
#   'date': '2020-12-12T19:42:49'},
#  {'url': 'https://globalnews.ca/?p=7518494',
#   'title': 'UPS shares &#8216;1st images&#8217; of coronavirus vaccine en route to Canada',
#   'date': '2020-12-12T19:42:44'},
#  {'url': 'https://globalnews.ca/?p=7518568',
#   'title': 'Calgary&#8217;s COVID-19 airport pilot program could expand to Edmonton',
#   'date': '2020-12-12T19:39:40'},
#  {'url': 'https://globalnews.ca/?p=7518455',
#   'title': 'N.B. government wage-freeze pitch &#8216;a slap in the face&#8217;: unions',
#   'date': '2020-12-12T19:33:48'},
#  {'url': 'https://globalnews.ca/?p=7518483',
#   'title': 'BC Ferries adds extra sailings, but passengers urged to avoid non-essential travel',
#   'date': '2020-12-12T19:09:20'},
#  {'url': 'https://globalnews.ca/?p=7518361',
#   'title': 'Coronavirus: Latest developments in the Greater Toronto Area on Dec. 12',
#   'date': '2020-12-12T19:02:52'},
#  {'url': 'https://globalnews.ca/?p=7518332',
#   'title': 'Nova Scotia reports 7 new COVID-19 cases on Saturday',
#   'date': '2020-12-12T18:57:28'},
#  {'url': 'https://globalnews.ca/?p=7518496',
#   'title': 'Toronto Raptors allow point guard Kyle Lowry to skip Charlotte trip',
#   'date': '2020-12-12T18:47:42'},
#  {'url': 'https://globalnews.ca/?p=7518493',
#   'title': '18 COVID-19 deaths in Manitoba Saturday, almost half connected to care homes',
#   'date': '2020-12-12T18:47:22'},
#  {'url': 'https://globalnews.ca/?p=7518486',
#   'title': '22-year-old woman arrested in Winnipeg homicide',
#   'date': '2020-12-12T18:46:21'},
#  {'url': 'https://globalnews.ca/?p=7518359',
#   'title': 'Canada-U.S. border closure extended to Jan. 21 as coronavirus cases soar, CBSA says',
#   'date': '2020-12-12T18:42:35'},
#  {'url': 'https://globalnews.ca/?p=7518433',
#   'title': 'Coronavirus: Walk-in testing available in Annapolis Valley and Kings County',
#   'date': '2020-12-12T18:07:16'},
#  {'url': 'https://globalnews.ca/?p=7518465',
#   'title': 'U.S. to rollout Pfizer’s coronavirus vaccine in 2 days: officials',
#   'date': '2020-12-12T18:05:46'},
#  {'url': 'https://globalnews.ca/?p=7518454',
#   'title': 'Toronto transit constables faulted for &#8216;excessive force&#8217; on streetcar passenger',
#   'date': '2020-12-12T17:59:12'},
#  {'url': 'https://globalnews.ca/?p=7516613',
#   'title': 'FAQ: What&#8217;s allowed during the holidays under B.C.&#8217;s COVID-19 restrictions?',
#   'date': '2020-12-12T17:48:50'},
#  {'url': 'https://globalnews.ca/?p=7511016',
#   'title': 'COMMENTARY: Not even SARS could prepare the hospitality industry for COVID-19',
#   'date': '2020-12-13T14:00:19'},
#  {'url': 'https://globalnews.ca?p=7519153&#038;preview=true&#038;preview_id=7519153',
#   'title': 'Trucks carrying 1st coronavirus vaccines in U.S. prepare to depart',
#   'date': '2020-12-13T13:29:42'},
#  {'url': 'https://globalnews.ca/?p=7519147',
#   'title': 'A look at Canadian peacekeeping 25 years after Rwanda',
#   'date': '2020-12-13T13:01:12'},
#  {'url': 'https://globalnews.ca?p=7519143&#038;preview=true&#038;preview_id=7519143',
#   'title': 'Some older Canadians decide to spend winter in Florida despite coronavirus pandemic',
#   'date': '2020-12-13T12:34:13'},
#  {'url': 'https://globalnews.ca?p=7519138&#038;preview=true&#038;preview_id=7519138',
#   'title': 'Coronavirus: Germany tightens lockdown restrictions as cases rise',
#   'date': '2020-12-13T12:18:26'},
#  {'url': 'https://globalnews.ca/?p=7519135',
#   'title': 'Post-Brexit trade deal talks will continue, U.K., European Union officials say',
#   'date': '2020-12-13T12:06:21'},
#  {'url': 'https://globalnews.ca/?p=7499917',
#   'title': 'The best morning and night time routines',
#   'date': '2020-12-13T11:00:42'},
#  {'url': 'https://globalnews.ca/?p=7512918',
#   'title': 'Coronavirus: Psychologists say to keep your family&#8217;s mental health in mind during the holidays',
#   'date': '2020-12-13T11:00:30'},
#  {'url': 'https://globalnews.ca/?p=7519092',
#   'title': '&#8216;SNL&#8217; cold open spoofs CNN interview with Fauci, Birx on coronavirus vaccine rollout',
#   'date': '2020-12-13T05:20:42'},
#  {'url': 'https://globalnews.ca/?p=7519057',
#   'title': 'Calgary fire crews battle apartment blaze',
#   'date': '2020-12-13T03:46:19'},
#  {'url': 'https://globalnews.ca/?p=7519065',
#   'title': '2 people killed, 1 person taken to hospital after Calgary collision, ASIRT investigating',
#   'date': '2020-12-13T03:36:58'},
#  {'url': 'https://globalnews.ca/?p=7518910',
#   'title': 'Fraser Health called Grinches for COVID-19 care home decoration rules',
#   'date': '2020-12-13T02:27:18'},
#  {'url': 'https://globalnews.ca/?p=7518895',
#   'title': 'Calgary city councillors to hear update on investigation into council expense policies',
#   'date': '2020-12-13T02:22:56'},
#  {'url': 'https://globalnews.ca/?p=7518983',
#   'title': 'Ontario COVID-19 ICU cases surpass 250, as additional lockdowns are set to be rolled out',
#   'date': '2020-12-13T02:22:30'},
#  {'url': 'https://globalnews.ca/?p=7518710',
#   'title': 'Calgary&#8217;s Olympic Plaza temporarily closed due to COVID-19 protest',
#   'date': '2020-12-13T01:56:28'},
#  {'url': 'https://globalnews.ca/?p=7518956',
#   'title': 'Hazardous construction material illegally dumped in north Kelowna neighbourhood: task force',
#   'date': '2020-12-13T01:32:55'},
#  {'url': 'http://globalnews.ca/?p=1148831',
#   'title': 'WATCH: Global National &#8211; December 12',
#   'date': '2020-12-13T01:00:05'},
#  {'url': 'https://globalnews.ca/?p=7514088',
#   'title': 'Stolen glow-in-the-dark equipment led to arrests: Saskatchewan fire chief',
#   'date': '2020-12-13T00:53:51'},
#  {'url': 'https://globalnews.ca?p=7518768&#038;preview=true&#038;preview_id=7518768',
#   'title': 'Health Canada warns people allergic to COVID-19 vaccine ingredients as cases surpass 450K',
#   'date': '2020-12-13T00:52:01'},
#  {'url': 'https://globalnews.ca/?p=7518955',
#   'title': 'Volunteers use flying flamethrower drone to incinerate wasp nests in China',
#   'date': '2020-12-13T00:50:09'},
#  {'url': 'https://globalnews.ca/?p=7518681',
#   'title': 'The uprising of India&#8217;s farmers: The significance and history behind the worldwide protests',
#   'date': '2020-12-13T00:26:18'},
#  {'url': 'https://globalnews.ca?p=7518760&#038;preview=true&#038;preview_id=7518760',
#   'title': 'Containing COVID-19 outbreak to single B.C. mink farm essential, say experts',
#   'date': '2020-12-12T23:51:52'},
#  {'url': 'https://globalnews.ca/?p=7518882',
#   'title': 'Coronavirus: Hundreds attend anti-restriction rally in downtown Kelowna',
#   'date': '2020-12-12T23:44:11'},
#  {'url': 'https://globalnews.ca/?p=7518579',
#   'title': 'Quebec government to fund $600,000 for Montreal Indigenous shelter&#8217;s relocation',
#   'date': '2020-12-12T23:26:15'},
#  {'url': 'https://globalnews.ca/?p=7518567',
#   'title': 'Calgary pools close as councillor seeks options for struggling inner city aquatic centre',
#   'date': '2020-12-12T23:21:00'},
#  {'url': 'https://globalnews.ca/?p=7518625',
#   'title': 'Calgary, Edmonton protesters rally against COVID-19 measures as Alberta adds 1,590 new cases',
#   'date': '2020-12-12T22:59:38'},
#  {'url': 'https://globalnews.ca/?p=7518754',
#   'title': 'Recovery of body from southwest, London, Ont., building collapse difficult due to &#8216;unstable structure&#8217;',
#   'date': '2020-12-12T22:40:27'},
#  {'url': 'https://globalnews.ca/?p=7518835',
#   'title': 'Charley Pride, country music legend, dies from coronavirus at 86',
#   'date': '2020-12-12T22:29:30'},
#  {'url': 'https://globalnews.ca/?p=7518791',
#   'title': '2 arrested for illegal night hunting with stolen firearm in Manitoba',
#   'date': '2020-12-12T22:13:14'},
#  {'url': 'https://globalnews.ca/?p=7518758',
#   'title': 'Regina family collecting, donating gifts to those in need over the holidays',
#   'date': '2020-12-12T22:10:53'},
#  {'url': 'https://globalnews.ca/?p=7518751',
#   'title': 'Hunter Biden subpoena seeks documents on dealings with former employer Burisma',
#   'date': '2020-12-12T21:46:20'},
#  {'url': 'https://globalnews.ca/?p=7518713',
#   'title': 'B.C. airline announces direct flights between Penticton and Vancouver',
#   'date': '2020-12-12T21:35:13'},
#  {'url': 'https://globalnews.ca/?p=7518676',
#   'title': 'New Out of the Cold shelter set to open Saturday night',
#   'date': '2020-12-12T21:15:25'},
#  {'url': 'https://globalnews.ca/?p=7518259',
#   'title': 'Canada to challenge U.S. softwood lumber export duties through World Trade Organization',
#   'date': '2020-12-12T21:13:02'},
#  {'url': 'https://globalnews.ca/?p=7518155',
#   'title': 'Rally held to protest loss of jobs, quality care at Bowmanville retirement home',
#   'date': '2020-12-12T21:05:58'},
#  {'url': 'https://globalnews.ca/?p=7518599',
#   'title': 'Pro, anti-Trump demonstrators clash during rally in Washington',
#   'date': '2020-12-12T21:01:37'},
#  {'url': 'https://globalnews.ca/?p=7518631',
#   'title': 'RCMP recommend charges against Chilliwack churches that broke COVID-19 restrictions',
#   'date': '2020-12-12T20:55:36'},
#  {'url': 'https://globalnews.ca/?p=7518653',
#   'title': 'Bailiff shot at while delivering court documents to Okotoks home: RCMP',
#   'date': '2020-12-12T20:30:12'},
#  {'url': 'https://globalnews.ca/?p=7518594',
#   'title': 'Saskatchewan reports 11 deaths, 274 new cases of coronavirus',
#   'date': '2020-12-12T20:29:11'},
#  {'url': 'https://globalnews.ca/?p=7518565',
#   'title': 'Coronavirus: With caseloads increasing, Interior Health urging residents to help limit spread',
#   'date': '2020-12-12T20:26:11'},
#  {'url': 'https://globalnews.ca/?p=7518378',
#   'title': 'Death linked to long-term care home, 32 new coronavirus cases in London and Middlesex',
#   'date': '2020-12-12T20:23:55'},
#  {'url': 'https://globalnews.ca/?p=7518633',
#   'title': 'Walking bridge built after New Brunswick woman stranded when storm washed out bridge',
#   'date': '2020-12-12T20:17:45'},
#  {'url': 'https://globalnews.ca/?p=7518514',
#   'title': '19-year-old man shot dead in East Vancouver in city&#8217;s 18th homicide of 2020',
#   'date': '2020-12-12T20:04:29'},
#  {'url': 'https://globalnews.ca/?p=7518519',
#   'title': 'Regina police issue two &#8220;Freedom Rally&#8221; organizers $2,800 fines',
#   'date': '2020-12-12T20:04:12'},
#  {'url': 'https://globalnews.ca/?p=7518608',
#   'title': 'Toronto police bean-bag shooting during mental-health call prompts SIU investigation',
#   'date': '2020-12-12T19:54:50'},
#  {'url': 'https://globalnews.ca/?p=7518559',
#   'title': 'RCMP lay charges after organized crime bust in Halifax',
#   'date': '2020-12-12T19:42:49'},
#  {'url': 'https://globalnews.ca/?p=7518494',
#   'title': 'UPS shares &#8216;1st images&#8217; of coronavirus vaccine en route to Canada',
#   'date': '2020-12-12T19:42:44'},
#  {'url': 'https://globalnews.ca/?p=7518568',
#   'title': 'Calgary&#8217;s COVID-19 airport pilot program could expand to Edmonton',
#   'date': '2020-12-12T19:39:40'},
#  {'url': 'https://globalnews.ca/?p=7518455',
#   'title': 'N.B. government wage-freeze pitch &#8216;a slap in the face&#8217;: unions',
#   'date': '2020-12-12T19:33:48'},
#  {'url': 'https://globalnews.ca/?p=7518483',
#   'title': 'BC Ferries adds extra sailings, but passengers urged to avoid non-essential travel',
#   'date': '2020-12-12T19:09:20'},
#  {'url': 'https://globalnews.ca/?p=7518361',
#   'title': 'Coronavirus: Latest developments in the Greater Toronto Area on Dec. 12',
#   'date': '2020-12-12T19:02:52'},
#  {'url': 'https://globalnews.ca/?p=7518332',
#   'title': 'Nova Scotia reports 7 new COVID-19 cases on Saturday',
#   'date': '2020-12-12T18:57:28'},
#  {'url': 'https://globalnews.ca/?p=7518496',
#   'title': 'Toronto Raptors allow point guard Kyle Lowry to skip Charlotte trip',
#   'date': '2020-12-12T18:47:42'},
#  {'url': 'https://globalnews.ca/?p=7518493',
#   'title': '18 COVID-19 deaths in Manitoba Saturday, almost half connected to care homes',
#   'date': '2020-12-12T18:47:22'},
#  {'url': 'https://globalnews.ca/?p=7518486',
#   'title': '22-year-old woman arrested in Winnipeg homicide',
#   'date': '2020-12-12T18:46:21'},
#  {'url': 'https://globalnews.ca/?p=7518359',
#   'title': 'Canada-U.S. border closure extended to Jan. 21 as coronavirus cases soar, CBSA says',
#   'date': '2020-12-12T18:42:35'},
#  {'url': 'https://globalnews.ca/?p=7518433',
#   'title': 'Coronavirus: Walk-in testing available in Annapolis Valley and Kings County',
#   'date': '2020-12-12T18:07:16'},
#  {'url': 'https://globalnews.ca/?p=7518465',
#   'title': 'U.S. to rollout Pfizer’s coronavirus vaccine in 2 days: officials',
#   'date': '2020-12-12T18:05:46'},
#  {'url': 'https://globalnews.ca/?p=7518454',
#   'title': 'Toronto transit constables faulted for &#8216;excessive force&#8217; on streetcar passenger',
#   'date': '2020-12-12T17:59:12'},
#  {'url': 'https://globalnews.ca/?p=7516613',
#   'title': 'FAQ: What&#8217;s allowed during the holidays under B.C.&#8217;s COVID-19 restrictions?',
#   'date': '2020-12-12T17:48:50'},
#  {'url': 'https://globalnews.ca/?p=7518422',
#   'title': 'More military support heading to Manitoba&#8217;s Shamattawa First Nation',
#   'date': '2020-12-12T17:38:32'},
#  {'url': 'https://globalnews.ca/?p=7518399',
#   'title': 'New Brunswick reports 1 new coronavirus case on Saturday',
#   'date': '2020-12-12T17:20:00'},
#  {'url': 'https://globalnews.ca?p=7518406&#038;preview=true&#038;preview_id=7518406',
#   'title': 'Quebec reports 40 additional COVID-19 deaths, 1,898 more cases',
#   'date': '2020-12-12T17:06:23'},
#  {'url': 'https://globalnews.ca/?p=7518382',
#   'title': 'Man charged after 2 police officers seriously injured in Toronto assault',
#   'date': '2020-12-12T16:50:11'},
#  {'url': 'https://globalnews.ca/?p=7518255',
#   'title': 'Recovery from coronavirus pandemic must include &#8216;ambitious&#8217; climate change plan: Trudeau',
#   'date': '2020-12-12T16:48:30'},
#  {'url': 'https://globalnews.ca/?p=7517319',
# ...
#   'title': 'Calgary&#8217;s COVID-19 airport pilot program could expand to Edmonton',
#   'date': '2020-12-12T19:39:40'},
#  {'url': 'https://globalnews.ca/?p=7518455',
#   'title': 'N.B. government wage-freeze pitch &#8216;a slap in the face&#8217;: unions',
#   'date': '2020-12-12T19:33:48'},
#  {'url': 'https://globalnews.ca/?p=7518483',
#   'title': 'BC Ferries adds extra sailings, but passengers urged to avoid non-essential travel',
#   'date': '2020-12-12T19:09:20'},
#  {'url': 'https://globalnews.ca/?p=7511016',
#   'title': 'COMMENTARY: Not even SARS could prepare the hospitality industry for COVID-19',
#   'date': '2020-12-13T14:00:19'},
#  {'url': 'https://globalnews.ca?p=7519153&#038;preview=true&#038;preview_id=7519153',
#   'title': 'Trucks carrying 1st coronavirus vaccines in U.S. prepare to depart',
#   'date': '2020-12-13T13:29:42'},
#  {'url': 'https://globalnews.ca/?p=7519147',
#   'title': 'A look at Canadian peacekeeping 25 years after Rwanda',
#   'date': '2020-12-13T13:01:12'},
#  {'url': 'https://globalnews.ca?p=7519143&#038;preview=true&#038;preview_id=7519143',
#   'title': 'Some older Canadians decide to spend winter in Florida despite coronavirus pandemic',
#   'date': '2020-12-13T12:34:13'},
#  {'url': 'https://globalnews.ca?p=7519138&#038;preview=true&#038;preview_id=7519138',
#   'title': 'Coronavirus: Germany tightens lockdown restrictions as cases rise',
#   'date': '2020-12-13T12:18:26'},
#  {'url': 'https://globalnews.ca/?p=7519135',
#   'title': 'Post-Brexit trade deal talks will continue, U.K., European Union officials say',
#   'date': '2020-12-13T12:06:21'},
#  {'url': 'https://globalnews.ca/?p=7499917',
#   'title': 'The best morning and night time routines',
#   'date': '2020-12-13T11:00:42'},
#  {'url': 'https://globalnews.ca/?p=7512918',
#   'title': 'Coronavirus: Psychologists say to keep your family&#8217;s mental health in mind during the holidays',
#   'date': '2020-12-13T11:00:30'},
#  {'url': 'https://globalnews.ca/?p=7519092',
#   'title': '&#8216;SNL&#8217; cold open spoofs CNN interview with Fauci, Birx on coronavirus vaccine rollout',
#   'date': '2020-12-13T05:20:42'},
#  {'url': 'https://globalnews.ca/?p=7519057',
#   'title': 'Calgary fire crews battle apartment blaze',
#   'date': '2020-12-13T03:46:19'},
#  {'url': 'https://globalnews.ca/?p=7519065',
#   'title': '2 people killed, 1 person taken to hospital after Calgary collision, ASIRT investigating',
#   'date': '2020-12-13T03:36:58'},
#  {'url': 'https://globalnews.ca/?p=7518910',
#   'title': 'Fraser Health called Grinches for COVID-19 care home decoration rules',
#   'date': '2020-12-13T02:27:18'},
#  {'url': 'https://globalnews.ca/?p=7518895',
#   'title': 'Calgary city councillors to hear update on investigation into council expense policies',
#   'date': '2020-12-13T02:22:56'},
#  {'url': 'https://globalnews.ca/?p=7518983',
#   'title': 'Ontario COVID-19 ICU cases surpass 250, as additional lockdowns are set to be rolled out',
#   'date': '2020-12-13T02:22:30'},
#  {'url': 'https://globalnews.ca/?p=7518710',
#   'title': 'Calgary&#8217;s Olympic Plaza temporarily closed due to COVID-19 protest',
#   'date': '2020-12-13T01:56:28'},
#  {'url': 'https://globalnews.ca/?p=7518956',
#   'title': 'Hazardous construction material illegally dumped in north Kelowna neighbourhood: task force',
#   'date': '2020-12-13T01:32:55'},
#  {'url': 'http://globalnews.ca/?p=1148831',
#   'title': 'WATCH: Global National &#8211; December 12',
#   'date': '2020-12-13T01:00:05'},
#  {'url': 'https://globalnews.ca/?p=7514088',
#   'title': 'Stolen glow-in-the-dark equipment led to arrests: Saskatchewan fire chief',
#   'date': '2020-12-13T00:53:51'},
#  {'url': 'https://globalnews.ca?p=7518768&#038;preview=true&#038;preview_id=7518768',
#   'title': 'Health Canada warns people allergic to COVID-19 vaccine ingredients as cases surpass 450K',
#   'date': '2020-12-13T00:52:01'},
#  {'url': 'https://globalnews.ca/?p=7518955',
#   'title': 'Volunteers use flying flamethrower drone to incinerate wasp nests in China',
#   'date': '2020-12-13T00:50:09'},
#  {'url': 'https://globalnews.ca/?p=7518681',
#   'title': 'The uprising of India&#8217;s farmers: The significance and history behind the worldwide protests',
#   'date': '2020-12-13T00:26:18'},
#  {'url': 'https://globalnews.ca?p=7518760&#038;preview=true&#038;preview_id=7518760',
#   'title': 'Containing COVID-19 outbreak to single B.C. mink farm essential, say experts',
#   'date': '2020-12-12T23:51:52'},
#  {'url': 'https://globalnews.ca/?p=7518882',
#   'title': 'Coronavirus: Hundreds attend anti-restriction rally in downtown Kelowna',
#   'date': '2020-12-12T23:44:11'},
#  {'url': 'https://globalnews.ca/?p=7518579',
#   'title': 'Quebec government to fund $600,000 for Montreal Indigenous shelter&#8217;s relocation',
#   'date': '2020-12-12T23:26:15'},
#  {'url': 'https://globalnews.ca/?p=7518567',
#   'title': 'Calgary pools close as councillor seeks options for struggling inner city aquatic centre',
#   'date': '2020-12-12T23:21:00'},
#  {'url': 'https://globalnews.ca/?p=7518625',
#   'title': 'Calgary, Edmonton protesters rally against COVID-19 measures as Alberta adds 1,590 new cases',
#   'date': '2020-12-12T22:59:38'},
#  {'url': 'https://globalnews.ca/?p=7518754',
#   'title': 'Recovery of body from southwest, London, Ont., building collapse difficult due to &#8216;unstable structure&#8217;',
#   'date': '2020-12-12T22:40:27'},
#  {'url': 'https://globalnews.ca/?p=7518835',
#   'title': 'Charley Pride, country music legend, dies from coronavirus at 86',
#   'date': '2020-12-12T22:29:30'},
#  {'url': 'https://globalnews.ca/?p=7518791',
#   'title': '2 arrested for illegal night hunting with stolen firearm in Manitoba',
#   'date': '2020-12-12T22:13:14'},
#  {'url': 'https://globalnews.ca/?p=7518758',
#   'title': 'Regina family collecting, donating gifts to those in need over the holidays',
#   'date': '2020-12-12T22:10:53'},
#  {'url': 'https://globalnews.ca/?p=7518751',
#   'title': 'Hunter Biden subpoena seeks documents on dealings with former employer Burisma',
#   'date': '2020-12-12T21:46:20'},
#  {'url': 'https://globalnews.ca/?p=7518713',
#   'title': 'B.C. airline announces direct flights between Penticton and Vancouver',
#   'date': '2020-12-12T21:35:13'},
#  {'url': 'https://globalnews.ca/?p=7518676',
#   'title': 'New Out of the Cold shelter set to open Saturday night',
#   'date': '2020-12-12T21:15:25'},
#  {'url': 'https://globalnews.ca/?p=7518259',
#   'title': 'Canada to challenge U.S. softwood lumber export duties through World Trade Organization',
#   'date': '2020-12-12T21:13:02'},
#  {'url': 'https://globalnews.ca/?p=7518155',
#   'title': 'Rally held to protest loss of jobs, quality care at Bowmanville retirement home',
#   'date': '2020-12-12T21:05:58'},
#  {'url': 'https://globalnews.ca/?p=7518599',
#   'title': 'Pro, anti-Trump demonstrators clash during rally in Washington',
#   'date': '2020-12-12T21:01:37'},
#  {'url': 'https://globalnews.ca/?p=7518631',
#   'title': 'RCMP recommend charges against Chilliwack churches that broke COVID-19 restrictions',
#   'date': '2020-12-12T20:55:36'},
#  {'url': 'https://globalnews.ca/?p=7518653',
#   'title': 'Bailiff shot at while delivering court documents to Okotoks home: RCMP',
#   'date': '2020-12-12T20:30:12'},
#  {'url': 'https://globalnews.ca/?p=7518594',
#   'title': 'Saskatchewan reports 11 deaths, 274 new cases of coronavirus',
#   'date': '2020-12-12T20:29:11'},
#  {'url': 'https://globalnews.ca/?p=7518565',
#   'title': 'Coronavirus: With caseloads increasing, Interior Health urging residents to help limit spread',
#   'date': '2020-12-12T20:26:11'},
#  {'url': 'https://globalnews.ca/?p=7518378',
#   'title': 'Death linked to long-term care home, 32 new coronavirus cases in London and Middlesex',
#   'date': '2020-12-12T20:23:55'},
#  {'url': 'https://globalnews.ca/?p=7518633',
#   'title': 'Walking bridge built after New Brunswick woman stranded when storm washed out bridge',
#   'date': '2020-12-12T20:17:45'},
#  {'url': 'https://globalnews.ca/?p=7518514',
#   'title': '19-year-old man shot dead in East Vancouver in city&#8217;s 18th homicide of 2020',
#   'date': '2020-12-12T20:04:29'},
#  {'url': 'https://globalnews.ca/?p=7518519',
#   'title': 'Regina police issue two &#8220;Freedom Rally&#8221; organizers $2,800 fines',
#   'date': '2020-12-12T20:04:12'},
#  {'url': 'https://globalnews.ca/?p=7518608',
#   'title': 'Toronto police bean-bag shooting during mental-health call prompts SIU investigation',
#   'date': '2020-12-12T19:54:50'},
#  {'url': 'https://globalnews.ca/?p=7518559',
#   'title': 'RCMP lay charges after organized crime bust in Halifax',
#   'date': '2020-12-12T19:42:49'},
#  {'url': 'https://globalnews.ca/?p=7518494',
#   'title': 'UPS shares &#8216;1st images&#8217; of coronavirus vaccine en route to Canada',
#   'date': '2020-12-12T19:42:44'},
#  {'url': 'https://globalnews.ca/?p=7518568',
#   'title': 'Calgary&#8217;s COVID-19 airport pilot program could expand to Edmonton',
#   'date': '2020-12-12T19:39:40'},
#  {'url': 'https://globalnews.ca/?p=7518455',
#   'title': 'N.B. government wage-freeze pitch &#8216;a slap in the face&#8217;: unions',
#   'date': '2020-12-12T19:33:48'},
#  {'url': 'https://globalnews.ca/?p=7518483',
#   'title': 'BC Ferries adds extra sailings, but passengers urged to avoid non-essential travel',
#   'date': '2020-12-12T19:09:20'},
#  {'url': 'https://globalnews.ca/?p=7518361',
#   'title': 'Coronavirus: Latest developments in the Greater Toronto Area on Dec. 12',
#   'date': '2020-12-12T19:02:52'},
#  {'url': 'https://globalnews.ca/?p=7518332',
#   'title': 'Nova Scotia reports 7 new COVID-19 cases on Saturday',
#   'date': '2020-12-12T18:57:28'},
#  {'url': 'https://globalnews.ca/?p=7518496',
#   'title': 'Toronto Raptors allow point guard Kyle Lowry to skip Charlotte trip',
#   'date': '2020-12-12T18:47:42'},
#  {'url': 'https://globalnews.ca/?p=7518493',
#   'title': '18 COVID-19 deaths in Manitoba Saturday, almost half connected to care homes',
#   'date': '2020-12-12T18:47:22'},
#  {'url': 'https://globalnews.ca/?p=7518486',
#   'title': '22-year-old woman arrested in Winnipeg homicide',
#   'date': '2020-12-12T18:46:21'},
#  {'url': 'https://globalnews.ca/?p=7518359',
#   'title': 'Canada-U.S. border closure extended to Jan. 21 as coronavirus cases soar, CBSA says',
#   'date': '2020-12-12T18:42:35'},
#  {'url': 'https://globalnews.ca/?p=7518433',
#   'title': 'Coronavirus: Walk-in testing available in Annapolis Valley and Kings County',
#   'date': '2020-12-12T18:07:16'},
#  {'url': 'https://globalnews.ca/?p=7518465',
#   'title': 'U.S. to rollout Pfizer’s coronavirus vaccine in 2 days: officials',
#   'date': '2020-12-12T18:05:46'},
#  {'url': 'https://globalnews.ca/?p=7518454',
#   'title': 'Toronto transit constables faulted for &#8216;excessive force&#8217; on streetcar passenger',
#   'date': '2020-12-12T17:59:12'},
#  {'url': 'https://globalnews.ca/?p=7516613',
#   'title': 'FAQ: What&#8217;s allowed during the holidays under B.C.&#8217;s COVID-19 restrictions?',
#   'date': '2020-12-12T17:48:50'},
#  {'url': 'https://globalnews.ca/?p=7518422',
#   'title': 'More military support heading to Manitoba&#8217;s Shamattawa First Nation',
#   'date': '2020-12-12T17:38:32'},
#  {'url': 'https://globalnews.ca/?p=7518399',
#   'title': 'New Brunswick reports 1 new coronavirus case on Saturday',
#   'date': '2020-12-12T17:20:00'},
#  {'url': 'https://globalnews.ca?p=7518406&#038;preview=true&#038;preview_id=7518406',
#   'title': 'Quebec reports 40 additional COVID-19 deaths, 1,898 more cases',
#   'date': '2020-12-12T17:06:23'},
#  {'url': 'https://globalnews.ca/?p=7518382',
#   'title': 'Man charged after 2 police officers seriously injured in Toronto assault',
#   'date': '2020-12-12T16:50:11'},
#  {'url': 'https://globalnews.ca/?p=7518255',
#   'title': 'Recovery from coronavirus pandemic must include &#8216;ambitious&#8217; climate change plan: Trudeau',
#   'date': '2020-12-12T16:48:30'},
#  {'url': 'https://globalnews.ca/?p=7517319',
#   'title': 'Daughter shares story after mom dies of COVID-19 at Regina&#8217;s Parkside Extendicare',
#   'date': '2020-12-12T16:47:09'},
#  {'url': 'https://globalnews.ca/?p=7518353',
#   'title': 'Coronavirus: Regina High Schools Athletic Association delays winter sports until February',
#   'date': '2020-12-12T16:40:53'},
#  {'url': 'https://globalnews.ca/?p=7517814',
#   'title': 'Nova Scotia RCMP investigate tampering with railway crossings',
#   'date': '2020-12-12T16:05:16'},
#  {'url': 'https://globalnews.ca/?p=7517899',
#   'title': 'COMMENTARY: Training exercise kerfuffle shows how badly Canada&#8217;s China policy needs fixing',
#   'date': '2020-12-12T16:00:02'},
#  {'url': 'https://globalnews.ca/?p=7518319',
#   'title': 'High-risk sex offender living in Heritage neighbourhood: Regina police',
#   'date': '2020-12-12T15:49:07'},
#  {'url': 'https://globalnews.ca?p=7518277&#038;preview=true&#038;preview_id=7518277',
#   'title': 'Ontario reports 1,873 new coronavirus cases, 17 deaths',
#   'date': '2020-12-12T15:17:49'},
#  {'url': 'https://globalnews.ca/?p=7518280',
#   'title': 'Some leaders in northern Saskatchewan cautiously optimistic for vaccine',
#   'date': '2020-12-12T14:59:03'},
#  {'url': 'https://globalnews.ca/?p=7518287',
#   'title': 'RCMP investigate break-in in Liverpool, N.S.',
#   'date': '2020-12-12T14:51:12'},
#  {'url': 'https://globalnews.ca/?p=7518254',
#   'title': 'Manitoba RCMP searching for missing 16-year-old girl',
#   'date': '2020-12-12T14:28:51'},
#  {'url': 'https://globalnews.ca/?p=7518268',
#   'title': '2 teens arrested after TTC employee stabbed at east-end subway station',
#   'date': '2020-12-12T14:17:56'},
#  {'url': 'https://globalnews.ca/?p=7493325',
#   'title': 'Your Saskatchewan photo of the day: December 2020',
#   'date': '2020-12-12T14:10:58'},
#  {'url': 'https://globalnews.ca/?p=7509011',
#   'title': 'COMMENTARY: COVID-19 ended Trump&#8217;s presidency after one term — and here&#8217;s why',
#   'date': '2020-12-12T14:00:34'},
#  {'url': 'https://globalnews.ca/?p=7515214',
#   'title': 'National award bestowed on Saskatchewan grandmother fighting impaired driving',
#   'date': '2020-12-12T13:35:27'},
#  {'url': 'https://globalnews.ca/?p=7518247',
#   'title': 'World leaders mark 5 years of Paris climate agreement with virtual gathering',
#   'date': '2020-12-12T13:19:44'},
#  {'url': 'https://globalnews.ca/?p=7518236',
#   'title': 'Manitoba announces initial plan for COVID-19 vaccine rollout',
#   'date': '2020-12-12T13:09:22'},
#  {'url': 'https://globalnews.ca/?p=7511016',
#   'title': 'COMMENTARY: Not even SARS could prepare the hospitality industry for COVID-19',
#   'date': '2020-12-13T14:00:19'},
#  {'url': 'https://globalnews.ca?p=7519153&#038;preview=true&#038;preview_id=7519153',
#   'title': 'Trucks carrying 1st coronavirus vaccines in U.S. prepare to depart',
#   'date': '2020-12-13T13:29:42'},
#  {'url': 'https://globalnews.ca/?p=7519147',
#   'title': 'A look at Canadian peacekeeping 25 years after Rwanda',
#   'date': '2020-12-13T13:01:12'},
#  {'url': 'https://globalnews.ca?p=7519143&#038;preview=true&#038;preview_id=7519143',
#   'title': 'Some older Canadians decide to spend winter in Florida despite coronavirus pandemic',
#   'date': '2020-12-13T12:34:13'},
#  {'url': 'https://globalnews.ca?p=7519138&#038;preview=true&#038;preview_id=7519138',
#   'title': 'Coronavirus: Germany tightens lockdown restrictions as cases rise',
#   'date': '2020-12-13T12:18:26'},
#  {'url': 'https://globalnews.ca/?p=7519135',
#   'title': 'Post-Brexit trade deal talks will continue, U.K., European Union officials say',
#   'date': '2020-12-13T12:06:21'},
#  {'url': 'https://globalnews.ca/?p=7499917',
#   'title': 'The best morning and night time routines',
#   'date': '2020-12-13T11:00:42'},
#  {'url': 'https://globalnews.ca/?p=7512918',
#   'title': 'Coronavirus: Psychologists say to keep your family&#8217;s mental health in mind during the holidays',
#   'date': '2020-12-13T11:00:30'},
#  {'url': 'https://globalnews.ca/?p=7519092',
#   'title': '&#8216;SNL&#8217; cold open spoofs CNN interview with Fauci, Birx on coronavirus vaccine rollout',
#   'date': '2020-12-13T05:20:42'},
#  {'url': 'https://globalnews.ca/?p=7519057',
#   'title': 'Calgary fire crews battle apartment blaze',
#   'date': '2020-12-13T03:46:19'},
#  ...]

# %%
# Almacenar los datos en un archivo json
with open('canada_global_news_links.json', 'w') as f:
    json.dump(all_data_crawler, f)

# %% [markdown]
# ## Scrapper

# %%
with open('canada_global_news_links.json') as json_file:
    data = json.load(json_file)

# %%
QUERY_CONTENT =  "//article[contains(@class, 'l-article__text') and contains(@class, 'js-story-text')]/p"

QUERY_CONTENT_JOURNALIST =  "//div[@class='c-byline__attribution']//span[@class='c-byline__name']/a/@title"

# %%
class Scraper:
    
    USER_AGENT_LIST = [
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1",
        "Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24"
    ]


    query_extract_text =  QUERY_CONTENT

    '''news_title = TITLE
    date = DATE'''

    def _init_(self):
        pass
    
    

    def clean_text(self, html_text):
        text_without_tags = w3lib.html.remove_tags(html_text)
        text_without_escape_chars = w3lib.html.replace_escape_chars(text_without_tags)
        text_without_escape_chars = html.unescape(text_without_escape_chars)
        text_without_whitespace = text_without_escape_chars.strip()
        return text_without_whitespace

    def replace_month_name_to_number(self,date_string):
        lower_string = date_string.lower()
        for month_id in range(1, 13):
            if(lower_string.find(calendar.month_name[month_id].lower())!=-1):
                if(month_id>=10):
                    return (lower_string.replace(calendar.month_name[month_id].lower(),str(month_id)))
                else:
                    return (lower_string.replace(calendar.month_name[month_id].lower(),"0"+str(month_id)))
            if(lower_string.find(calendar.month_abbr[month_id].lower())!=-1):
                if(month_id>=10):
                    return (lower_string.replace(calendar.month_abbr[month_id].lower(),str(month_id)))
                else:
                    return (lower_string.replace(calendar.month_abbr[month_id].lower(),"0"+str(month_id)))
                    
    #Se puede modificar
    def format_date(self,date):
        date = date.split("T")[0]
        return(date)

    #Se puede modificar
    def parse(self, response):
        self.news_text = []
        self.message_to_send = []
        self.scraped_url = response.url

        ''' self.news_title = self.clean_text(self.news_title)
        self.date = self.clean_text(self.date)
        self.date = self.format_date(self.date)'''
        
        news_text_extracted_response = response.html.xpath(self.query_extract_text)
        for part_of_body in news_text_extracted_response:
            stripped_html_tags = w3lib.html.remove_tags(part_of_body.text)
            text_cleaned = self.clean_text(stripped_html_tags)
            self.news_text.append(text_cleaned)

    def start_request(self,url):
        headers = {'user-agent':random.choice(self.USER_AGENT_LIST) }
        session = HTMLSession()
        response = session.get(url,headers=headers)        
        return response

# %%
##Definir esto porque lo necesita el scrapper
'''news_title = TITLE
date = DATE'''

SEED_SCRAP = data[0]['url']

# %%
scraper = Scraper()
response =scraper.start_request(SEED_SCRAP)

# %%
response
# Out:
# <Response [200]>

# %%
scraper.parse(response)

# %%
scraper.news_text
# Out:
# ['A virulent virus, worried travellers and a tourism sector on the brink. Sounds like 2020? In fact, this was the experience in a few global cities in 2002 and 2003.',
#  'Toronto was one of them. The city’s battle against a deadly virus — and the struggle for the rehabilitation of its damaged tourism sector — offers lessons for cities wondering how they will navigate a post-COVID world. And even plan for the next crisis, whenever it arrives.',
#  'Hotels, as places of refuge, pleasure, business and also contagion, are important places to explore how the tourism sector pilots its way through pandemics. The experience with SARS offers sobering lessons for Toronto and urban tourist destinations globally.',
#  'How are the tourism crises of 2002-03 and today similar, and how do they differ? Both public health crisis resulted in sudden, dramatic declines in hotel occupancy. However, while all travel came to a sudden stop globally in 2020, the 2002-03 events centred on a few cities, with Toronto, Singapore and Hong Kong under the microscope.',
#  'Hotel occupancy rates in these cities recorded steep declines, as travellers headed elsewhere, businesses suspended events and worried airlines and public health authorities explored protocols such as the now-ubiquitous face masks.',
#  'The collapse in travel in winter 2020 occurred at a point when the overall economy and the travel sector were in robust shape and recording record profits. In 2002-03, circumstances were very different. Global travel had slowed due to the Iraq War. Increasing documentation requirements and lingering concerns over security after 9/11 reduced cross-border traffic between Canada and the United States.',
#  'The arrival of SARS dealt a body blow to Canada’s largest city.',
#  'Both SARS and COVID-19 have had a severe impact on tourism and travel. Hotels are barometers of Toronto’s economic condition, and reveal the unequal impacts pandemics have on employment. Marginally employed people — immigrants and low-income workers — are over-represented among hotel workers. They lose their jobs quickly in the face of reduced demand.',
#  'Seasonal employment prospects also dim in the face of disruption. As in summer 2020, student summer employment was impacted in 2003, especially as Toronto entered the crucial summer months back, briefly, on the World Health Organization’s SARS travel advisory. The blow dealt to the tourism sector locally was hard but, as it turned out, by no means fatal.',
#  'Toronto’s experience with SARS suggests that once a place appears safe, reassured travellers return — with some coaxing and a lot of co-ordinated planning. In late spring 2003, Toronto businesses developed a co-ordinated response to recovery. Travel packages that included accommodation, restaurant reservations, sporting events and theatre tickets began to lure tourists back. This promotion was accompanied by an aggressive and co-ordinated roll-back of gasoline prices.',
#  'The SARS crisis also led to the creation of a body for the tourism and hospitality sector, chaired by Tourism Toronto, which aimed to restore the city’s reputation. Local and provincial governments committed funds for advertising to reassure prospective tourists that Toronto was safe. The federal government also announced additional funds to promote Canada as a destination in international markets.',
#  'The most famous part of the reputation rehabilitation strategy was the hosting of the July 30, 2003, SARS benefit concert. Several hundred thousand fans cheered a lineup of world-famous musicians, headlined by the Rolling Stones. The results of that mega-event are hard to measure in terms of impact, despite the large and enthusiastic crowds that it drew. Such an event is unimaginable today, with the timeline for the COVID-19’s defeat far off, and the certainty that doubts will linger about the wisdom of such boisterous, large-scale assemblies for a long time to come.',
#  'In 2003, good news for the tourism sector arrived quickly. In fact, by late 2004, hotels were recording pre-SARS occupancy levels. It seemed as if the sector had dodged a bullet. But it had also dodged a critical opportunity to reflect on how new technologies and standards might reduce the impact of a future pandemic. And this is perhaps where the comparison proves most illuminating.',
#  'The hotel sector faces dramatically different conditions today. It is in the midst of a global pandemic affecting all sectors of the economy. SARS resulted in far fewer deaths, over a shorter period of time, in a small number of major cities.',
#  'While the story of hotels’ recovery is inspiring, the pace was so fast that few paused to ask is larger lessons would be learned: What vulnerabilities might have been disguised in the rush to restore Toronto’s dynamic tourism sector? How could new technologies, systematic contingency planning and early detection systems might have become integrated into hotel management post-2003?',
#  'The greatest lesson of SARS may be how, amid the excited focus on recovery and a return to normalcy, so little thought was given to structurally prepare for the prospect of future crises. We need to keep these lessons in mind as we plan our emergence from COVID-19, and the resumption of travel.',
#  'Kevin James, Professor, History, University of Guelph; Jose Gabriel Alonzo, Masters student, History, University of Guelph, and Mark Holmes, Assistant Professor, Business and Economics, University of Guelph',
#  'This article is republished from The Conversation under a Creative Commons licence. Read the original article.']
